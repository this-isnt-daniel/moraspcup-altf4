# %% [markdown]
# # Gated U-Net Hyperparameter Sweep
# Systematically sweeps training hyperparameters (learning rate, loss weighting) while
# keeping the **exact same GatedUNet architecture** and data pipeline as `nafnet_script.ipynb`.
#
# Each run is evaluated with:
# 1. The notebook's own fast diagnostic score (CUDA SSIM)
# 2. The official `evaluation/evaluate.py` (skimage SSIM, the real competition metric)
# 3. A clean CPU-only inference benchmark
#
# Results are appended to `hparam_sweep_results.csv` — never overwritten.

# %% [markdown]
# ## Cell 1 — Paths, Packages & Device

# %%
import subprocess, sys
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q',
                       'pillow', 'numpy', 'pandas', 'matplotlib', 'scikit-image', 'tqdm'])

from pathlib import Path
import os, json, random, time, hashlib, math, copy, platform
import numpy as np
import pandas as pd
import torch
import torch.nn.functional as F
from torch import nn
from tqdm.auto import tqdm

# ── Paths ──────────────────────────────────────────────────────────────────
# Resolve repo root robustly: this notebook lives in scripts/, so go up one level.
# Works whether you run from the repo root OR from inside the scripts/ folder.
_nb_dir = Path(__file__).resolve().parent if '__file__' in dir() else Path.cwd()
REPO_ROOT = next(
    (p for p in [_nb_dir] + list(_nb_dir.parents)
     if (p / 'competition_data').is_dir()),
    _nb_dir
)
DATASET_ROOT   = REPO_ROOT / 'competition_data'
EVAL_SCRIPT    = REPO_ROOT / 'evaluation' / 'evaluate.py'

TRAIN_NOISY_DIR = DATASET_ROOT / 'public' / 'noisy'
TRAIN_CLEAN_DIR = DATASET_ROOT / 'public' / 'ground_truth'
TEST_DIR        = DATASET_ROOT / 'submissions' / 'noisy'

SWEEP_ROOT = REPO_ROOT / 'sweep_outputs'
SWEEP_ROOT.mkdir(parents=True, exist_ok=True)

RESULTS_CSV = SWEEP_ROOT / 'hparam_sweep_results.csv'

# ── Shared constants (match original notebook) ──────────────────────────────
BASE_CFG = dict(
    seed=42, width=24, blocks=2, patch=128, batch=4,
    steps_per_epoch=150, epochs=25,
    weight_decay=1e-4, ssim_weight=0.0,
    ema_decay=0.995, val_fraction=0.10,
    patience=8, tile=384, overlap=64, amp=True,
    cache_images=True, num_workers=0,
)

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if DEVICE.type == 'cuda':
    print('GPU:', torch.cuda.get_device_name(0))
    print('VRAM GiB:', round(torch.cuda.get_device_properties(0).total_memory / 2**30, 2))
else:
    raise RuntimeError('Select a GPU runtime before running the sweep — training without CUDA will take days.')
print('Outputs:', SWEEP_ROOT)
# Out:
# GPU: NVIDIA GeForce RTX 5050 Laptop GPU
# VRAM GiB: 7.96
# Outputs: c:\Daniel\Projects\moraspcup-altf4\sweep_outputs

# %% [markdown]
# ## Cell 2 — Image Indexer & Dataset Integrity Check

# %%
from PIL import Image
import re

EXTS = {'.png', '.jpg', '.jpeg', '.tif', '.tiff'}

def index_folder(folder, noisy):
    result = {}
    for p in sorted(folder.iterdir()):
        if p.suffix.lower() not in EXTS or not p.is_file(): continue
        m = re.fullmatch(r'(\d+)_noise' if noisy else r'(\d+)', p.stem)
        if not m: raise ValueError(f'Unexpected filename: {p.name}')
        i = int(m.group(1))
        if i in result: raise ValueError(f'Duplicate ID: {i}')
        result[i] = p
    return result

noisy_paths = index_folder(TRAIN_NOISY_DIR, True)
clean_paths = index_folder(TRAIN_CLEAN_DIR, False)
test_paths  = index_folder(TEST_DIR, True) if TEST_DIR.exists() else {}

for label, mapping, expected in [('noisy', noisy_paths, set(range(1,461))),
                                  ('clean', clean_paths, set(range(1,461)))]:
    if set(mapping) != expected:
        raise ValueError(f'{label}: missing={sorted(expected-set(mapping))}')
    for i, p in mapping.items():
        exp_name = f'{i:03d}_noise.png' if label != 'clean' else f'{i:03d}.png'
        if p.name != exp_name: raise ValueError(f'Expected {exp_name}, found {p.name}')

# Infer channels from first image
with Image.open(clean_paths[1]) as im:
    CHANNELS = 3 if im.mode == 'RGB' else 1
BASE_CFG['channels'] = CHANNELS
print(f'Dataset: {len(noisy_paths)} noisy / {len(clean_paths)} clean pairs | Channels: {CHANNELS}')
# Out:
# Dataset: 460 noisy / 460 clean pairs | Channels: 3

# %% [markdown]
# ## Cell 3 — I/O Helpers & Fast Diagnostic Metrics

# %%
def read_image(path):
    with Image.open(path) as im:
        a = np.asarray(im)
        if im.mode not in ('RGB','L') or a.dtype != np.uint8:
            raise ValueError(f'Only uint8 RGB/L supported: {path}')
    if a.ndim == 2: a = a[..., None]
    return np.array(a, copy=True)

def quantize(a):
    return np.rint(np.clip(a, 0, 1) * 255).astype(np.uint8)

def write_image(path, a):
    a = quantize(a)
    Image.fromarray(a[..., 0] if a.shape[-1] == 1 else a).save(path)

def _fast_psnr(a, b):
    mse = np.mean((a - b) ** 2)
    return float('inf') if mse == 0 else 10 * math.log10(1.0 / mse)

def _fast_ssim(a, b):
    dev = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    if a.ndim == 2: a = a[..., None]
    if b.ndim == 2: b = b[..., None]
    a_t = torch.from_numpy(a).float().permute(2,0,1).unsqueeze(0).to(dev)
    b_t = torch.from_numpy(b).float().permute(2,0,1).unsqueeze(0).to(dev)
    C = a_t.shape[1]
    w = torch.ones((C,1,7,7), device=dev) / 49.0
    ap = F.pad(a_t, (3,3,3,3), mode='reflect')
    bp = F.pad(b_t, (3,3,3,3), mode='reflect')
    mu_a = F.conv2d(ap, w, groups=C); mu_b = F.conv2d(bp, w, groups=C)
    sa = (F.conv2d(ap**2, w, groups=C) - mu_a**2) * (49.0/48.0)
    sb = (F.conv2d(bp**2, w, groups=C) - mu_b**2) * (49.0/48.0)
    sab = (F.conv2d(ap*bp, w, groups=C) - mu_a*mu_b) * (49.0/48.0)
    C1 = 0.0001; C2 = 0.0009
    ssim_map = ((2*mu_a*mu_b+C1)*(2*sab+C2)) / ((mu_a**2+mu_b**2+C1)*(sa+sb+C2))
    return ssim_map.mean().item()

def metric_row(noisy, clean, pred):
    x = clean.astype(np.float64)/255
    y = noisy.astype(np.float64)/255
    z = quantize(pred).astype(np.float64)/255
    pn,sn = _fast_psnr(x,y), _fast_ssim(x.astype(np.float32), y.astype(np.float32))
    pp,sp = _fast_psnr(x,z), _fast_ssim(x.astype(np.float32), z.astype(np.float32))
    dp = pp - pn if math.isfinite(pn) else -math.inf
    score = 0.6*np.clip(dp/15,0,1) + 0.4*max(sp-sn, 0)
    return dict(psnr=pp, ssim=sp, noisy_psnr=pn, noisy_ssim=sn,
                delta_psnr=dp, delta_ssim=sp-sn, score=float(score))

print('I/O helpers and fast CUDA SSIM ready.')
# Out:
# I/O helpers and fast CUDA SSIM ready.

# %% [markdown]
# ## Cell 4 — Duplicate-Grouping Train / Val Split
# Exact copy of the grouping logic from `nafnet_script.ipynb`. The split is shared across
# all sweep runs (same seed, same val fraction) so results are directly comparable.

# %%
GROUPS_CSV = ''   # optional path to a CSV with columns [id, group]

random.seed(BASE_CFG['seed']); np.random.seed(BASE_CFG['seed']); torch.manual_seed(BASE_CFG['seed'])
if torch.cuda.is_available(): torch.cuda.manual_seed_all(BASE_CFG['seed'])

parent = {i:i for i in clean_paths}
def root(i):
    while parent[i] != i:
        parent[i] = parent[parent[i]]; i = parent[i]
    return i
def union(a,b): parent[root(b)] = root(a)

seen = {}
for i, p in tqdm(clean_paths.items(), desc='Grouping exact duplicates'):
    digest = hashlib.sha256(read_image(p).tobytes()).hexdigest()
    if digest in seen: union(i, seen[digest])
    else: seen[digest] = i

if GROUPS_CSV:
    groups = pd.read_csv(GROUPS_CSV)
    for _, g in groups.groupby('group'):
        ids = g['id'].astype(int).tolist()
        for i in ids[1:]: union(ids[0], i)

clusters = {}
for i in clean_paths: clusters.setdefault(root(i), []).append(i)
keys = list(clusters); random.Random(BASE_CFG['seed']).shuffle(keys)

val_ids = []
for key in keys:
    if len(val_ids) >= round(len(clean_paths) * BASE_CFG['val_fraction']): break
    val_ids.extend(clusters[key])
val_ids = sorted(val_ids)
train_ids = sorted(set(clean_paths) - set(val_ids))
print(f'Train: {len(train_ids)}  Val: {len(val_ids)}')
SPLIT = {'train': train_ids, 'val': val_ids}
(SWEEP_ROOT / 'split.json').write_text(json.dumps(SPLIT, indent=2))
# Out:
# Grouping exact duplicates:   0%|          | 0/460 [00:00<?, ?it/s]
# Train: 414  Val: 46
# 4066

# %% [markdown]
# ## Cell 5 — Model Architecture
# Verbatim copy of `ChannelNorm`, `GatedBlock`, and `Denoiser` from `nafnet_script.ipynb`.
# **Do NOT modify** — we are sweeping training hyperparameters only, not architecture.

# %%
class ChannelNorm(nn.Module):
    def __init__(self,c):
        super().__init__(); self.w=nn.Parameter(torch.ones(1,c,1,1)); self.b=nn.Parameter(torch.zeros(1,c,1,1))
    def forward(self,x):
        dtype=x.dtype; z=x.float(); mu=z.mean(1,keepdim=True)
        z=(z-mu)*torch.rsqrt((z-mu).square().mean(1,keepdim=True)+1e-6)
        return (z*self.w+self.b).to(dtype)

class GatedBlock(nn.Module):
    def __init__(self,c):
        super().__init__()
        self.n1=ChannelNorm(c); self.n2=ChannelNorm(c)
        self.expand=nn.Conv2d(c,2*c,1); self.depth=nn.Conv2d(2*c,2*c,3,padding=1,groups=2*c)
        self.attn=nn.Sequential(nn.AdaptiveAvgPool2d(1),nn.Conv2d(c,c,1))
        self.project=nn.Conv2d(c,c,1); self.f1=nn.Conv2d(c,2*c,1); self.f2=nn.Conv2d(c,c,1)
        self.beta=nn.Parameter(torch.zeros(1,c,1,1)); self.gamma=nn.Parameter(torch.zeros(1,c,1,1))
    def forward(self,x):
        a,b=self.depth(self.expand(self.n1(x))).chunk(2,1); z=a*b
        x=x+self.beta*self.project(z*self.attn(z))
        a,b=self.f1(self.n2(x)).chunk(2,1)
        return x+self.gamma*self.f2(a*b)

class Denoiser(nn.Module):
    def __init__(self,channels=3,width=24,blocks=2):
        super().__init__(); self.channels=channels
        self.head=nn.Conv2d(channels,width,3,padding=1)
        self.enc=nn.ModuleList(); self.down=nn.ModuleList(); self.up=nn.ModuleList(); self.dec=nn.ModuleList()
        c=width
        for _ in range(3):
            self.enc.append(nn.Sequential(*[GatedBlock(c) for _ in range(blocks)]))
            self.down.append(nn.Conv2d(c,2*c,2,stride=2)); c*=2
        self.mid=nn.Sequential(*[GatedBlock(c) for _ in range(blocks+2)])
        for _ in range(3):
            self.up.append(nn.Sequential(nn.Conv2d(c,2*c,1),nn.PixelShuffle(2))); c//=2
            self.dec.append(nn.Sequential(*[GatedBlock(c) for _ in range(blocks)]))
        self.tail=nn.Conv2d(width,channels,3,padding=1)
        nn.init.zeros_(self.tail.weight); nn.init.zeros_(self.tail.bias)
    def forward(self,x):
        h,w=x.shape[-2:]; p=F.pad(x,(0,(-w)%8,0,(-h)%8),mode='replicate')
        z=self.head(p); skips=[]
        for enc,down in zip(self.enc,self.down): z=enc(z); skips.append(z); z=down(z)
        z=self.mid(z)
        for up,dec,s in zip(self.up,self.dec,reversed(skips)): z=dec(up(z)+s)
        return (p+self.tail(z))[...,:h,:w]

# Sanity check
with torch.no_grad():
    probe = torch.rand(1, CHANNELS, 65, 71).to(DEVICE)
    _tmp = Denoiser(CHANNELS, BASE_CFG['width'], BASE_CFG['blocks']).to(DEVICE)
    assert _tmp(probe).shape == probe.shape
    assert torch.allclose(_tmp(probe), probe)
    del _tmp, probe
print('PASS: Architecture shape and initial identity checks.')
print('Parameters:', sum(p.numel() for p in Denoiser(CHANNELS, BASE_CFG['width'], BASE_CFG['blocks']).parameters()))
# Out:
# PASS: Architecture shape and initial identity checks.
# Parameters: 1614267

# %% [markdown]
# ## Cell 6 — Tiled Inference & Wavelet Fallback

# %%
def tiled(model, x, tile=384, overlap=64):
    if tile <= overlap or overlap < 0: raise ValueError('Require 0 <= overlap < tile')
    h, w = x.shape[-2:]
    if h <= tile and w <= tile: return model(x).float()
    def starts(n):
        if n <= tile: return [0]
        return sorted(set(list(range(0, n-tile+1, tile-overlap)) + [n-tile]))
    out = torch.zeros_like(x, dtype=torch.float32)
    weights = torch.zeros_like(x[:,:1], dtype=torch.float32)
    for top in starts(h):
        for left in starts(w):
            patch = x[..., top:top+tile, left:left+tile]; ph, pw = patch.shape[-2:]
            wy = torch.hann_window(ph, periodic=False, device=x.device).clamp_min(.05)
            wx = torch.hann_window(pw, periodic=False, device=x.device).clamp_min(.05)
            weight = (wy[:,None]*wx[None,:])[None,None]
            out[..., top:top+ph, left:left+pw] += model(patch).float() * weight
            weights[..., top:top+ph, left:left+pw] += weight
    return out / weights

@torch.inference_mode()
def predict(model, array, device, tile=384, overlap=64):
    x = torch.from_numpy(np.ascontiguousarray(array.transpose(2,0,1))).float()[None].to(device) / 255
    model.eval()
    result = tiled(model, x, tile, overlap).clamp(0,1)[0].permute(1,2,0).cpu().numpy()
    if not np.isfinite(result).all(): raise FloatingPointError('Nonfinite prediction')
    return result

def wavelet_prediction(array):
    from skimage.restoration import denoise_wavelet
    x = array.astype(np.float32) / 255
    if x.shape[-1] == 1:
        out = denoise_wavelet(x[...,0], method='BayesShrink', mode='soft',
                              rescale_sigma=True, channel_axis=None)[..., None]
    else:
        out = denoise_wavelet(x, method='BayesShrink', mode='soft',
                              rescale_sigma=True, channel_axis=-1, convert2ycbcr=True)
    return np.clip(out, 0, 1).astype(np.float32)

print('Inference helpers ready.')
# Out:
# Inference helpers ready.

# %% [markdown]
# ## Cell 7 — Training Dataset & DataLoader

# %%
from torch.utils.data import Dataset, DataLoader

class PairedPatches(Dataset):
    def __init__(self, ids, patch_size, cache=True):
        self.ids = ids; self.patch_size = patch_size; self.cache = {} if cache else None
    def __len__(self): return BASE_CFG['steps_per_epoch'] * BASE_CFG['batch']
    def __getitem__(self, _):
        i = random.choice(self.ids)
        if self.cache is not None and i in self.cache:
            y, x = self.cache[i]
        else:
            y, x = read_image(noisy_paths[i]), read_image(clean_paths[i])
            if self.cache is not None: self.cache[i] = (y, x)
        p = self.patch_size; h, w = y.shape[:2]
        top = random.randrange(h-p+1); left = random.randrange(w-p+1)
        y = y[top:top+p, left:left+p]; x = x[top:top+p, left:left+p]
        k = random.randrange(4); y = np.rot90(y,k); x = np.rot90(x,k)
        if random.random() < .5: y = y[:,::-1]; x = x[:,::-1]
        return tuple(torch.from_numpy(np.ascontiguousarray(a.transpose(2,0,1))).float()/255 for a in (y,x))

print('Dataset class ready.')
# Out:
# Dataset class ready.

# %% [markdown]
# ## Cell 8 — Hyperparameter Grid
# Defines the sweep configurations. Max 4 training runs (2 LRs × 2 loss weightings).
# Alpha blending is swept at evaluation time only — no extra training runs needed.

# %%
# ── Sweep grid ──────────────────────────────────────────────────────────────
SWEEP_GRID = [
    dict(run_id='run_lr1e4_charb',  lr=1e-4, loss_weighting='charbonnier_only',    patch_size=128),
    dict(run_id='run_lr1e4_ssim',   lr=1e-4, loss_weighting='charbonnier_plus_ssim', patch_size=128),
    dict(run_id='run_lr3e4_charb',  lr=3e-4, loss_weighting='charbonnier_only',    patch_size=128),
    dict(run_id='run_lr3e4_ssim',   lr=3e-4, loss_weighting='charbonnier_plus_ssim', patch_size=128),
]

ALPHA_CANDIDATES = [0.0, 0.1, 0.2]  # swept at eval time only

print(f'Grid has {len(SWEEP_GRID)} training runs × {len(ALPHA_CANDIDATES)} alpha values at eval time.')
print('Estimated training time: 30-50 min per run on a T4 GPU (25 epochs × ~150 steps).')
for cfg in SWEEP_GRID:
    print(f"  {cfg['run_id']:30s} lr={cfg['lr']:.0e}  loss={cfg['loss_weighting']}")
# Out:
# Grid has 4 training runs × 3 alpha values at eval time.
# Estimated training time: 30-50 min per run on a T4 GPU (25 epochs × ~150 steps).
#   run_lr1e4_charb                lr=1e-04  loss=charbonnier_only
#   run_lr1e4_ssim                 lr=1e-04  loss=charbonnier_plus_ssim
#   run_lr3e4_charb                lr=3e-04  loss=charbonnier_only
#   run_lr3e4_ssim                 lr=3e-04  loss=charbonnier_plus_ssim

# %% [markdown]
# ## Cell 9 — Loss Functions (Charbonnier + optional SSIM)

# %%
def charbonnier_loss(pred, target, eps=1e-3):
    return torch.sqrt((pred.float() - target.float())**2 + eps**2).mean()

def structural_loss(a, b):
    a, b = a.float(), b.float()
    mu_a = F.avg_pool2d(a,7,1); mu_b = F.avg_pool2d(b,7,1)
    va = F.avg_pool2d(a*a,7,1) - mu_a*mu_a
    vb = F.avg_pool2d(b*b,7,1) - mu_b*mu_b
    cov = F.avg_pool2d(a*b,7,1) - mu_a*mu_b
    s = ((2*mu_a*mu_b+.01**2)*(2*cov+.03**2)) / ((mu_a.square()+mu_b.square()+.01**2)*(va+vb+.03**2))
    return 1 - s.mean()

def make_loss_fn(loss_weighting):
    if loss_weighting == 'charbonnier_only':
        return lambda pred, tgt: charbonnier_loss(pred, tgt)
    elif loss_weighting == 'charbonnier_plus_ssim':
        return lambda pred, tgt: charbonnier_loss(pred, tgt) + 0.15 * structural_loss(pred, tgt)
    else:
        raise ValueError(f'Unknown loss_weighting: {loss_weighting}')

print('Loss functions ready.')
# Out:
# Loss functions ready.

# %% [markdown]
# ## Cell 10 — Training Runner & Diagnostic Evaluator

# %%
def atomic_save(obj, path):
    tmp = path.with_suffix(path.suffix + '.tmp')
    torch.save(obj, tmp); os.replace(tmp, path)

def diagnostic_evaluate(net, val_ids_list, tile, overlap, device):
    """Fast diagnostic evaluation on val set using GPU SSIM."""
    rows = []
    for i in tqdm(val_ids_list, desc='Val eval', leave=False):
        y = read_image(noisy_paths[i]); x = read_image(clean_paths[i])
        pred = predict(net, y, device, tile, overlap)
        if device.type == 'cuda': torch.cuda.synchronize()
        rows.append(metric_row(y, x, pred))
    frame = pd.DataFrame(rows)
    return frame, frame.mean().to_dict()

def run_training(run_cfg, seed=42):
    """Train one configuration from scratch. Returns (history, best_ckpt_path)."""
    run_id = run_cfg['run_id']
    lr = run_cfg['lr']
    loss_weighting = run_cfg['loss_weighting']
    patch_size = run_cfg['patch_size']

    run_dir = SWEEP_ROOT / run_id
    ckpt_dir = run_dir / 'checkpoints'
    run_dir.mkdir(parents=True, exist_ok=True)
    ckpt_dir.mkdir(parents=True, exist_ok=True)

    # Seed per-run
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed)
    if DEVICE.type == 'cuda': torch.cuda.manual_seed_all(seed)

    cfg = dict(BASE_CFG)
    cfg.update(lr=lr, patch=patch_size)

    model = Denoiser(CHANNELS, cfg['width'], cfg['blocks']).to(DEVICE)
    ema = copy.deepcopy(model).eval()
    for p in ema.parameters(): p.requires_grad_(False)

    loss_fn = make_loss_fn(loss_weighting)

    def lr_factor(epoch):
        if epoch < 3: return (epoch+1)/3
        progress = min(1, max(0, (epoch-3)/max(1, cfg['epochs']-3)))
        return .05 + .95*.5*(1+math.cos(math.pi*progress))

    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=cfg['weight_decay'])
    scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_factor)
    AMP = cfg['amp'] and DEVICE.type == 'cuda'
    scaler = torch.amp.GradScaler('cuda', enabled=AMP)

    dataset = PairedPatches(train_ids, patch_size, cache=True)
    loader = DataLoader(dataset, batch_size=cfg['batch'], num_workers=0,
                        pin_memory=DEVICE.type == 'cuda')

    history = []
    best_score = -float('inf')
    best_ckpt = ckpt_dir / f'{run_id}_best.pth'
    stale = 0

    print(f'\n{"="*60}')
    print(f'Starting: {run_id}')
    print(f'  lr={lr:.0e}  loss={loss_weighting}  patch={patch_size}  epochs={cfg["epochs"]}')
    print(f'{"="*60}')

    for epoch in range(cfg['epochs']):
        model.train(); losses = []; started = time.perf_counter()
        if DEVICE.type == 'cuda': torch.cuda.reset_peak_memory_stats()
        bar = tqdm(loader, desc=f'[{run_id}] Epoch {epoch+1}/{cfg["epochs"]}')
        nan_detected = False
        for noisy_b, clean_b in bar:
            noisy_b = noisy_b.to(DEVICE, non_blocking=True)
            clean_b = clean_b.to(DEVICE, non_blocking=True)
            optimizer.zero_grad(set_to_none=True)
            try:
                with torch.autocast(device_type=DEVICE.type, enabled=AMP):
                    pred = model(noisy_b); loss = loss_fn(pred, clean_b)
                if not torch.isfinite(loss):
                    print(f'WARNING: NaN/Inf loss at epoch {epoch+1}, step {len(losses)}. Skipping run.')
                    nan_detected = True; break
                scaler.scale(loss).backward(); scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                old_scale = scaler.get_scale(); scaler.step(optimizer); scaler.update()
                stepped = scaler.get_scale() >= old_scale
            except torch.cuda.OutOfMemoryError:
                optimizer.zero_grad(set_to_none=True); torch.cuda.empty_cache()
                print(f'WARNING: GPU OOM on run {run_id}. Skipping.')
                nan_detected = True; break
            if stepped:
                with torch.no_grad():
                    for ep, p in zip(ema.parameters(), model.parameters()): ep.lerp_(p, 1-cfg['ema_decay'])
            losses.append(float(loss.detach())); bar.set_postfix(loss=np.mean(losses[-20:]))

        if nan_detected:
            print(f'Run {run_id} aborted due to NaN/OOM.')
            return history, None

        _, raw_metrics = diagnostic_evaluate(model, val_ids, cfg['tile'], cfg['overlap'], DEVICE)
        _, ema_metrics = diagnostic_evaluate(ema, val_ids, cfg['tile'], cfg['overlap'], DEVICE)
        candidates = [('raw', model, raw_metrics), ('ema', ema, ema_metrics)]
        kind, winner, metrics = max(candidates, key=lambda item: item[2]['score'])

        improved = metrics['score'] > best_score
        if improved:
            best_score = metrics['score']
            state = {'model': {k:v.detach().cpu() for k,v in winner.state_dict().items()},
                     'config': dict(cfg), 'epoch': epoch, 'metrics': metrics, 'split': SPLIT}
            atomic_save(state, best_ckpt)
            stale = 0
        else:
            stale += 1

        elapsed = time.perf_counter() - started
        row = dict(epoch=epoch+1, loss=float(np.mean(losses)),
                   lr=optimizer.param_groups[0]['lr'],
                   raw_score=raw_metrics['score'], ema_score=ema_metrics['score'],
                   selected_score=metrics['score'], selected=kind,
                   psnr=metrics['psnr'], ssim=metrics['ssim'], seconds=elapsed)
        history.append(row)
        scheduler.step()

        still_improving = epoch >= 3 and history[-1]['selected_score'] - history[-2]['selected_score'] > 0.001
        suffix = ' ↑' if improved else (' ≈' if still_improving else '')
        print(f"  Epoch {epoch+1:2d} | loss={row['loss']:.4f} | score={metrics['score']:.4f}{suffix} | "
              f"psnr={metrics['psnr']:.2f} | {elapsed:.0f}s")

        pd.DataFrame(history).to_csv(run_dir / 'training_history.csv', index=False)

        if stale >= cfg['patience']:
            print(f'Early stopping at epoch {epoch+1}. Best score: {best_score:.4f}')
            break

        # After first epoch, print time estimate for the whole sweep
        if epoch == 0:
            remaining_epochs = cfg['epochs'] - 1
            remaining_runs = len(SWEEP_GRID) - list(r['run_id'] for r in SWEEP_GRID).index(run_id) - 1
            total_remaining_s = elapsed * (remaining_epochs + remaining_runs * cfg['epochs'])
            print(f'\n  ⏱  Estimated remaining sweep time: {total_remaining_s/3600:.1f} h '
                  f'({remaining_runs} more runs + {remaining_epochs} more epochs this run)\n')

    still_improving_at_end = (len(history) == cfg['epochs'] and
                               history[-1]['selected_score'] - history[-5]['selected_score'] > 0.01)
    if still_improving_at_end:
        print(f'  ⚠️  Run {run_id} was still clearly improving at epoch {cfg["epochs"]} — consider more epochs.')

    return history, best_ckpt

print('Training runner ready.')
# Out:
# Training runner ready.

# %% [markdown]
# ## Cell 11 — Official Evaluator (via evaluation/evaluate.py)
# Writes predicted images to disk then calls the official script via subprocess.
# This gives the **true competition score** using skimage SSIM with win_size=7,
# gaussian_weights=False — matching the official evaluation exactly.

# %%
def official_eval_on_full_set(model_or_ckpt_path, run_id, alpha=0.0,
                               tile=384, overlap=64):
    """
    Run the official evaluate.py on all 460 public images.
    Returns dict with official mean composite score, psnr, ssim.
    """
    pred_dir = SWEEP_ROOT / run_id / f'preds_alpha{alpha:.2f}'
    pred_dir.mkdir(parents=True, exist_ok=True)

    # Load model if path given
    if isinstance(model_or_ckpt_path, Path):
        state = torch.load(model_or_ckpt_path, map_location='cpu', weights_only=False)
        c = state['config']
        net = Denoiser(c['channels'], c['width'], c['blocks'])
        net.load_state_dict(state['model'])
        net = net.to(DEVICE).eval()
    else:
        net = model_or_ckpt_path

    all_ids = sorted(noisy_paths.keys())
    print(f'  Running inference on {len(all_ids)} images (alpha={alpha})...')
    for i in tqdm(all_ids, desc='Official inference', leave=False):
        y = read_image(noisy_paths[i])
        pred = predict(net, y, DEVICE, tile, overlap)
        if alpha > 0:
            wav = wavelet_prediction(y)
            pred = (1 - alpha) * pred + alpha * wav
        pred = np.clip(pred, 0, 1)
        write_image(pred_dir / f'{i:03d}.png', pred)

    # Call official evaluate.py
    result = subprocess.run(
        [sys.executable, str(EVAL_SCRIPT),
         '--noisy_dir', str(TRAIN_NOISY_DIR),
         '--pred_dir',  str(pred_dir),
         '--gt_dir',    str(TRAIN_CLEAN_DIR)],
        capture_output=True, text=True
    )
    output = result.stdout + result.stderr
    print(result.stdout)

    # Parse output
    def extract(key):
        import re
        m = re.search(key + r'\s*([\d.]+)', output)
        return float(m.group(1)) if m else float('nan')

    return dict(
        composite=extract('Composite Score:'),
        psnr=extract('Mean PSNR:'),
        ssim=extract('Mean SSIM:'),
    )

print('Official evaluator wrapper ready.')
print('Evaluator script:', EVAL_SCRIPT, '(exists:', EVAL_SCRIPT.exists(), ')')
# Out:
# Official evaluator wrapper ready.
# Evaluator script: c:\Daniel\Projects\moraspcup-altf4\evaluation\evaluate.py (exists: True )

# %% [markdown]
# ## Cell 12 — CPU-Only Inference Benchmark

# %%
def cpu_benchmark(ckpt_path, alpha=0.0, tile=384, overlap=64, n_warmup=3, n_measure=10):
    """
    Clean CPU-only benchmark. Model loaded OUTSIDE timing loop.
    3 warmup passes discarded, then 10 measured passes.
    alpha-blend cost included if alpha > 0 (realistic inference cost).
    """
    state = torch.load(ckpt_path, map_location='cpu', weights_only=False)
    c = state['config']
    net = Denoiser(c['channels'], c['width'], c['blocks'])
    net.load_state_dict(state['model'])
    net = net.cpu().eval()

    # Pick 10 random images for measurement
    rng = random.Random(42)
    measure_ids = rng.sample(sorted(noisy_paths.keys()), n_measure + n_warmup)

    times = []
    for idx, i in enumerate(measure_ids):
        y = read_image(noisy_paths[i])
        t0 = time.perf_counter()
        pred = predict(net, y, torch.device('cpu'), tile, overlap)
        if alpha > 0:
            wav = wavelet_prediction(y)
            pred = (1 - alpha) * pred + alpha * wav
        elapsed = (time.perf_counter() - t0) * 1000  # ms
        if idx >= n_warmup:
            times.append(elapsed)
        print(f'  {"warmup" if idx < n_warmup else "MEASURE"} {idx+1}/{n_warmup+n_measure}: {elapsed:.0f} ms')

    mean_ms = np.mean(times)
    std_ms = np.std(times)
    print(f'\nCPU benchmark: {mean_ms:.1f} ± {std_ms:.1f} ms/image (alpha={alpha})')
    return mean_ms, std_ms

print('CPU benchmark ready.')
# Out:
# CPU benchmark ready.

# %% [markdown]
# ## Cell 13 — Run the Full Sweep
# This is the main cell. Run it after all setup cells above. Each run trains a fresh model
# from scratch, picks the best checkpoint (raw vs EMA), sweeps alpha at eval time,
# runs the official evaluator, benchmarks CPU inference, then appends results to CSV.

# %%
import datetime

all_results = []

for run_cfg in SWEEP_GRID:
    run_id = run_cfg['run_id']
    print(f'\n{"#"*65}')
    print(f'# Sweep run: {run_id}')
    print(f'{"#"*65}')

    # ── Train ──────────────────────────────────────────────────────────────
    try:
        history, best_ckpt = run_training(run_cfg)
    except Exception as exc:
        print(f'ERROR in training {run_id}: {exc}')
        continue

    if best_ckpt is None or not best_ckpt.exists():
        print(f'Skipping {run_id} — no valid checkpoint saved.')
        continue

    epochs_trained = len(history)
    last5_gain = history[-1]['selected_score'] - history[max(0,len(history)-6)]['selected_score']
    still_improving = last5_gain > 0.01

    # ── Diagnostic score (already computed during training) ────────────────
    best_diag_score = max(r['selected_score'] for r in history)
    diag_psnr = max(r['psnr'] for r in history)
    diag_ssim = max(r['ssim'] for r in history)

    # ── Load best checkpoint model ─────────────────────────────────────────
    state = torch.load(best_ckpt, map_location='cpu', weights_only=False)
    c = state['config']
    net = Denoiser(c['channels'], c['width'], c['blocks'])
    net.load_state_dict(state['model'])
    net = net.to(DEVICE).eval()

    # ── Alpha sweep at eval time ───────────────────────────────────────────
    print('\nSweeping alpha...')
    best_alpha = 0.0; best_official = -float('inf'); best_psnr = 0.0; best_ssim_val = 0.0
    alpha_results = []
    for alpha in ALPHA_CANDIDATES:
        try:
            official = official_eval_on_full_set(best_ckpt, run_id, alpha=alpha,
                                                  tile=BASE_CFG['tile'], overlap=BASE_CFG['overlap'])
            print(f'  alpha={alpha:.1f}: official_composite={official["composite"]:.4f} '
                  f'psnr={official["psnr"]:.2f} ssim={official["ssim"]:.4f}')
            alpha_results.append((alpha, official))
            if official['composite'] > best_official:
                best_official = official['composite']
                best_alpha = alpha
                best_psnr = official['psnr']
                best_ssim_val = official['ssim']
        except Exception as exc:
            print(f'  WARNING: official eval failed for alpha={alpha}: {exc}')

    print(f'  Best alpha: {best_alpha} → composite={best_official:.4f}')

    # ── Diagnostic vs official gap ─────────────────────────────────────────
    gap = best_diag_score - best_official
    print(f'\n  Diagnostic score: {best_diag_score:.4f}')
    print(f'  Official score:   {best_official:.4f}')
    print(f'  Gap (diag-official): {gap:+.4f}')

    # ── CPU benchmark ──────────────────────────────────────────────────────
    print('\nRunning CPU benchmark...')
    try:
        cpu_mean, cpu_std = cpu_benchmark(best_ckpt, alpha=best_alpha,
                                           tile=BASE_CFG['tile'], overlap=BASE_CFG['overlap'])
    except Exception as exc:
        print(f'  WARNING: CPU benchmark failed: {exc}')
        cpu_mean, cpu_std = float('nan'), float('nan')

    # ── Append to results ──────────────────────────────────────────────────
    row = dict(
        run_id=run_id,
        learning_rate=run_cfg['lr'],
        loss_weighting=run_cfg['loss_weighting'],
        patch_size=run_cfg['patch_size'],
        epochs_trained=epochs_trained,
        still_improving_at_end=still_improving,
        best_alpha=best_alpha,
        notebook_diagnostic_score=round(best_diag_score, 6),
        official_evaluate_score=round(best_official, 6),
        diag_vs_official_gap=round(gap, 6),
        mean_psnr=round(best_psnr, 4),
        mean_ssim=round(best_ssim_val, 6),
        cpu_ms_per_image=round(cpu_mean, 2),
        cpu_ms_std=round(cpu_std, 2),
        timestamp=datetime.datetime.now().isoformat(timespec='seconds'),
    )
    all_results.append(row)

    # Append-only CSV
    df_row = pd.DataFrame([row])
    if RESULTS_CSV.exists():
        df_row.to_csv(RESULTS_CSV, mode='a', header=False, index=False)
    else:
        df_row.to_csv(RESULTS_CSV, index=False)

    print(f'\nResult saved: {row}')

print('\n' + '='*65)
print('ALL RUNS COMPLETE')
print('='*65)
# Out:
# #################################################################
# # Sweep run: run_lr1e4_charb
# #################################################################
#
# ============================================================
# Starting: run_lr1e4_charb
#   lr=1e-04  loss=charbonnier_only  patch=128  epochs=25
# ============================================================
# [run_lr1e4_charb] Epoch 1/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  1 | loss=0.0801 | score=0.0287 ↑ | psnr=20.54 | 78s
#
#   ⏱  Estimated remaining sweep time: 2.1 h (3 more runs + 24 more epochs this run)
# [run_lr1e4_charb] Epoch 2/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  2 | loss=0.0724 | score=0.1249 ↑ | psnr=22.27 | 57s
# [run_lr1e4_charb] Epoch 3/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  3 | loss=0.0530 | score=0.3008 ↑ | psnr=25.31 | 54s
# [run_lr1e4_charb] Epoch 4/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  4 | loss=0.0405 | score=0.3792 ↑ | psnr=26.66 | 52s
# [run_lr1e4_charb] Epoch 5/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  5 | loss=0.0369 | score=0.4065 ↑ | psnr=27.08 | 52s
# [run_lr1e4_charb] Epoch 6/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  6 | loss=0.0353 | score=0.4293 ↑ | psnr=27.51 | 53s
# [run_lr1e4_charb] Epoch 7/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  7 | loss=0.0333 | score=0.4356 ↑ | psnr=27.60 | 75s
# [run_lr1e4_charb] Epoch 8/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  8 | loss=0.0338 | score=0.4408 ↑ | psnr=27.70 | 49s
# [run_lr1e4_charb] Epoch 9/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  9 | loss=0.0343 | score=0.4443 ↑ | psnr=27.78 | 50s
# [run_lr1e4_charb] Epoch 10/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 10 | loss=0.0331 | score=0.4464 ↑ | psnr=27.83 | 50s
# [run_lr1e4_charb] Epoch 11/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 11 | loss=0.0332 | score=0.4503 ↑ | psnr=27.90 | 50s
# [run_lr1e4_charb] Epoch 12/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 12 | loss=0.0333 | score=0.4535 ↑ | psnr=27.96 | 50s
# [run_lr1e4_charb] Epoch 13/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 13 | loss=0.0329 | score=0.4559 ↑ | psnr=28.01 | 50s
# [run_lr1e4_charb] Epoch 14/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 14 | loss=0.0323 | score=0.4573 ↑ | psnr=28.04 | 50s
# [run_lr1e4_charb] Epoch 15/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 15 | loss=0.0329 | score=0.4587 ↑ | psnr=28.07 | 49s
# [run_lr1e4_charb] Epoch 16/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 16 | loss=0.0327 | score=0.4597 ↑ | psnr=28.09 | 50s
# [run_lr1e4_charb] Epoch 17/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 17 | loss=0.0326 | score=0.4612 ↑ | psnr=28.12 | 49s
# [run_lr1e4_charb] Epoch 18/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 18 | loss=0.0320 | score=0.4616 ↑ | psnr=28.13 | 50s
# [run_lr1e4_charb] Epoch 19/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 19 | loss=0.0327 | score=0.4623 ↑ | psnr=28.14 | 49s
# [run_lr1e4_charb] Epoch 20/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 20 | loss=0.0323 | score=0.4627 ↑ | psnr=28.15 | 49s
# [run_lr1e4_charb] Epoch 21/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 21 | loss=0.0321 | score=0.4632 ↑ | psnr=28.16 | 49s
# [run_lr1e4_charb] Epoch 22/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 22 | loss=0.0321 | score=0.4640 ↑ | psnr=28.17 | 50s
# [run_lr1e4_charb] Epoch 23/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 23 | loss=0.0320 | score=0.4641 ↑ | psnr=28.18 | 49s
# [run_lr1e4_charb] Epoch 24/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 24 | loss=0.0320 | score=0.4642 ↑ | psnr=28.18 | 49s
# [run_lr1e4_charb] Epoch 25/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 25 | loss=0.0315 | score=0.4646 ↑ | psnr=28.18 | 49s
#
# Sweeping alpha...
#   Running inference on 460 images (alpha=0.0)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           28.0586 dB
# Mean SSIM:           0.818392
# Mean Delta PSNR:     +8.2329 dB
# Mean Delta SSIM:     +0.354008
#
# Composite Score:     0.47091847
# ==============================================
#
#   alpha=0.0: official_composite=0.4709 psnr=28.06 ssim=0.8184
#   Running inference on 460 images (alpha=0.1)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           28.1673 dB
# Mean SSIM:           0.822713
# Mean Delta PSNR:     +8.3416 dB
# Mean Delta SSIM:     +0.358329
#
# Composite Score:     0.47699570
# ==============================================
#
#   alpha=0.1: official_composite=0.4770 psnr=28.17 ssim=0.8227
#   Running inference on 460 images (alpha=0.2)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           28.1866 dB
# Mean SSIM:           0.824816
# Mean Delta PSNR:     +8.3609 dB
# Mean Delta SSIM:     +0.360432
#
# Composite Score:     0.47860969
# ==============================================
#
#   alpha=0.2: official_composite=0.4786 psnr=28.19 ssim=0.8248
#   Best alpha: 0.2 → composite=0.4786
#
#   Diagnostic score: 0.4646
#   Official score:   0.4786
#   Gap (diag-official): -0.0140
#
# Running CPU benchmark...
#   warmup 1/13: 3785 ms
#   warmup 2/13: 3588 ms
#   warmup 3/13: 3634 ms
#   MEASURE 4/13: 3446 ms
#   MEASURE 5/13: 3704 ms
#   MEASURE 6/13: 3571 ms
#   MEASURE 7/13: 3533 ms
#   MEASURE 8/13: 3697 ms
#   MEASURE 9/13: 3668 ms
#   MEASURE 10/13: 3410 ms
#   MEASURE 11/13: 3554 ms
#   MEASURE 12/13: 3552 ms
#   MEASURE 13/13: 3470 ms
#
# CPU benchmark: 3560.6 ± 97.9 ms/image (alpha=0.2)
#
# Result saved: {'run_id': 'run_lr1e4_charb', 'learning_rate': 0.0001, 'loss_weighting': 'charbonnier_only', 'patch_size': 128, 'epochs_trained': 25, 'still_improving_at_end': False, 'best_alpha': 0.2, 'notebook_diagnostic_score': 0.464608, 'official_evaluate_score': 0.47861, 'diag_vs_official_gap': -0.014002, 'mean_psnr': 28.1866, 'mean_ssim': 0.824816, 'cpu_ms_per_image': 3560.57, 'cpu_ms_std': 97.88, 'timestamp': '2026-09-19T02:28:14'}
#
# #################################################################
# # Sweep run: run_lr1e4_ssim
# #################################################################
#
# ============================================================
# Starting: run_lr1e4_ssim
#   lr=1e-04  loss=charbonnier_plus_ssim  patch=128  epochs=25
# ============================================================
# [run_lr1e4_ssim] Epoch 1/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  1 | loss=0.1571 | score=0.0332 ↑ | psnr=20.61 | 63s
#
#   ⏱  Estimated remaining sweep time: 1.3 h (2 more runs + 24 more epochs this run)
# [run_lr1e4_ssim] Epoch 2/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  2 | loss=0.1408 | score=0.1509 ↑ | psnr=22.70 | 54s
# [run_lr1e4_ssim] Epoch 3/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  3 | loss=0.1002 | score=0.3455 ↑ | psnr=26.03 | 51s
# [run_lr1e4_ssim] Epoch 4/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  4 | loss=0.0707 | score=0.4143 ↑ | psnr=27.15 | 50s
# [run_lr1e4_ssim] Epoch 5/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  5 | loss=0.0649 | score=0.4248 ↑ | psnr=27.25 | 50s
# [run_lr1e4_ssim] Epoch 6/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  6 | loss=0.0628 | score=0.4374 ↑ | psnr=27.51 | 50s
# [run_lr1e4_ssim] Epoch 7/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  7 | loss=0.0598 | score=0.4416 ↑ | psnr=27.58 | 50s
# [run_lr1e4_ssim] Epoch 8/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  8 | loss=0.0599 | score=0.4456 ↑ | psnr=27.65 | 51s
# [run_lr1e4_ssim] Epoch 9/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  9 | loss=0.0614 | score=0.4500 ↑ | psnr=27.76 | 50s
# [run_lr1e4_ssim] Epoch 10/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 10 | loss=0.0598 | score=0.4509 ↑ | psnr=27.78 | 50s
# [run_lr1e4_ssim] Epoch 11/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 11 | loss=0.0586 | score=0.4539 ↑ | psnr=27.84 | 50s
# [run_lr1e4_ssim] Epoch 12/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 12 | loss=0.0594 | score=0.4561 ↑ | psnr=27.88 | 50s
# [run_lr1e4_ssim] Epoch 13/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 13 | loss=0.0588 | score=0.4579 ↑ | psnr=27.92 | 50s
# [run_lr1e4_ssim] Epoch 14/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 14 | loss=0.0576 | score=0.4592 ↑ | psnr=27.94 | 50s
# [run_lr1e4_ssim] Epoch 15/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 15 | loss=0.0576 | score=0.4613 ↑ | psnr=28.01 | 50s
# [run_lr1e4_ssim] Epoch 16/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 16 | loss=0.0585 | score=0.4625 ↑ | psnr=28.02 | 50s
# [run_lr1e4_ssim] Epoch 17/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 17 | loss=0.0578 | score=0.4641 ↑ | psnr=28.05 | 50s
# [run_lr1e4_ssim] Epoch 18/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 18 | loss=0.0575 | score=0.4637 | psnr=28.04 | 50s
# [run_lr1e4_ssim] Epoch 19/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 19 | loss=0.0577 | score=0.4640 | psnr=28.04 | 50s
# [run_lr1e4_ssim] Epoch 20/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 20 | loss=0.0574 | score=0.4656 ↑ | psnr=28.08 | 50s
# [run_lr1e4_ssim] Epoch 21/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 21 | loss=0.0569 | score=0.4653 | psnr=28.07 | 50s
# [run_lr1e4_ssim] Epoch 22/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 22 | loss=0.0572 | score=0.4660 ↑ | psnr=28.08 | 50s
# [run_lr1e4_ssim] Epoch 23/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 23 | loss=0.0567 | score=0.4662 ↑ | psnr=28.09 | 50s
# [run_lr1e4_ssim] Epoch 24/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 24 | loss=0.0573 | score=0.4661 | psnr=28.08 | 50s
# [run_lr1e4_ssim] Epoch 25/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 25 | loss=0.0561 | score=0.4661 | psnr=28.08 | 50s
#
# Sweeping alpha...
#   Running inference on 460 images (alpha=0.0)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           27.9862 dB
# Mean SSIM:           0.832316
# Mean Delta PSNR:     +8.1605 dB
# Mean Delta SSIM:     +0.367932
#
# Composite Score:     0.47365911
# ==============================================
#
#   alpha=0.0: official_composite=0.4737 psnr=27.99 ssim=0.8323
#   Running inference on 460 images (alpha=0.1)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           28.1217 dB
# Mean SSIM:           0.835923
# Mean Delta PSNR:     +8.2960 dB
# Mean Delta SSIM:     +0.371539
#
# Composite Score:     0.48046681
# ==============================================
#
#   alpha=0.1: official_composite=0.4805 psnr=28.12 ssim=0.8359
#   Running inference on 460 images (alpha=0.2)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           28.1657 dB
# Mean SSIM:           0.836897
# Mean Delta PSNR:     +8.3400 dB
# Mean Delta SSIM:     +0.372514
#
# Composite Score:     0.48260601
# ==============================================
#
#   alpha=0.2: official_composite=0.4826 psnr=28.17 ssim=0.8369
#   Best alpha: 0.2 → composite=0.4826
#
#   Diagnostic score: 0.4662
#   Official score:   0.4826
#   Gap (diag-official): -0.0164
#
# Running CPU benchmark...
#   warmup 1/13: 3693 ms
#   warmup 2/13: 3843 ms
#   warmup 3/13: 3637 ms
#   MEASURE 4/13: 3493 ms
#   MEASURE 5/13: 3674 ms
#   MEASURE 6/13: 3742 ms
#   MEASURE 7/13: 3467 ms
#   MEASURE 8/13: 3714 ms
#   MEASURE 9/13: 3654 ms
#   MEASURE 10/13: 3623 ms
#   MEASURE 11/13: 3684 ms
#   MEASURE 12/13: 3476 ms
#   MEASURE 13/13: 3601 ms
#
# CPU benchmark: 3612.8 ± 95.8 ms/image (alpha=0.2)
#
# Result saved: {'run_id': 'run_lr1e4_ssim', 'learning_rate': 0.0001, 'loss_weighting': 'charbonnier_plus_ssim', 'patch_size': 128, 'epochs_trained': 25, 'still_improving_at_end': False, 'best_alpha': 0.2, 'notebook_diagnostic_score': 0.46617, 'official_evaluate_score': 0.482606, 'diag_vs_official_gap': -0.016436, 'mean_psnr': 28.1657, 'mean_ssim': 0.836897, 'cpu_ms_per_image': 3612.81, 'cpu_ms_std': 95.81, 'timestamp': '2026-09-19T03:16:05'}
#
# #################################################################
# # Sweep run: run_lr3e4_charb
# #################################################################
#
# ============================================================
# Starting: run_lr3e4_charb
#   lr=3e-04  loss=charbonnier_only  patch=128  epochs=25
# ============================================================
# [run_lr3e4_charb] Epoch 1/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  1 | loss=0.0753 | score=0.1050 ↑ | psnr=21.93 | 64s
#
#   ⏱  Estimated remaining sweep time: 0.9 h (1 more runs + 24 more epochs this run)
# [run_lr3e4_charb] Epoch 2/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  2 | loss=0.0495 | score=0.3627 ↑ | psnr=26.35 | 54s
# [run_lr3e4_charb] Epoch 3/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  3 | loss=0.0370 | score=0.4227 ↑ | psnr=27.34 | 51s
# [run_lr3e4_charb] Epoch 4/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  4 | loss=0.0341 | score=0.4410 ↑ | psnr=27.68 | 50s
# [run_lr3e4_charb] Epoch 5/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  5 | loss=0.0338 | score=0.4424 ↑ | psnr=27.67 | 50s
# [run_lr3e4_charb] Epoch 6/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  6 | loss=0.0331 | score=0.4554 ↑ | psnr=27.95 | 50s
# [run_lr3e4_charb] Epoch 7/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  7 | loss=0.0317 | score=0.4576 ↑ | psnr=27.99 | 50s
# [run_lr3e4_charb] Epoch 8/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  8 | loss=0.0324 | score=0.4639 ↑ | psnr=28.13 | 50s
# [run_lr3e4_charb] Epoch 9/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  9 | loss=0.0327 | score=0.4674 ↑ | psnr=28.20 | 50s
# [run_lr3e4_charb] Epoch 10/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 10 | loss=0.0316 | score=0.4694 ↑ | psnr=28.23 | 49s
# [run_lr3e4_charb] Epoch 11/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 11 | loss=0.0315 | score=0.4816 ↑ | psnr=28.41 | 50s
# [run_lr3e4_charb] Epoch 12/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 12 | loss=0.0310 | score=0.4950 ↑ | psnr=28.64 | 50s
# [run_lr3e4_charb] Epoch 13/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 13 | loss=0.0301 | score=0.5043 ↑ | psnr=28.80 | 49s
# [run_lr3e4_charb] Epoch 14/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 14 | loss=0.0294 | score=0.5103 ↑ | psnr=28.90 | 49s
# [run_lr3e4_charb] Epoch 15/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 15 | loss=0.0299 | score=0.5156 ↑ | psnr=29.03 | 50s
# [run_lr3e4_charb] Epoch 16/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 16 | loss=0.0294 | score=0.5207 ↑ | psnr=29.13 | 50s
# [run_lr3e4_charb] Epoch 17/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 17 | loss=0.0290 | score=0.5249 ↑ | psnr=29.21 | 50s
# [run_lr3e4_charb] Epoch 18/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 18 | loss=0.0283 | score=0.5273 ↑ | psnr=29.24 | 49s
# [run_lr3e4_charb] Epoch 19/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 19 | loss=0.0292 | score=0.5286 ↑ | psnr=29.26 | 50s
# [run_lr3e4_charb] Epoch 20/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 20 | loss=0.0286 | score=0.5303 ↑ | psnr=29.29 | 50s
# [run_lr3e4_charb] Epoch 21/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 21 | loss=0.0285 | score=0.5321 ↑ | psnr=29.33 | 50s
# [run_lr3e4_charb] Epoch 22/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 22 | loss=0.0282 | score=0.5334 ↑ | psnr=29.35 | 50s
# [run_lr3e4_charb] Epoch 23/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 23 | loss=0.0282 | score=0.5349 ↑ | psnr=29.38 | 50s
# [run_lr3e4_charb] Epoch 24/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 24 | loss=0.0279 | score=0.5356 ↑ | psnr=29.40 | 50s
# [run_lr3e4_charb] Epoch 25/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 25 | loss=0.0275 | score=0.5360 ↑ | psnr=29.41 | 50s
#
# Sweeping alpha...
#   Running inference on 460 images (alpha=0.0)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           29.2880 dB
# Mean SSIM:           0.872325
# Mean Delta PSNR:     +9.4623 dB
# Mean Delta SSIM:     +0.407941
#
# Composite Score:     0.54149450
# ==============================================
#
#   alpha=0.0: official_composite=0.5415 psnr=29.29 ssim=0.8723
#   Running inference on 460 images (alpha=0.1)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           29.2683 dB
# Mean SSIM:           0.872133
# Mean Delta PSNR:     +9.4426 dB
# Mean Delta SSIM:     +0.407749
#
# Composite Score:     0.54055382
# ==============================================
#
#   alpha=0.1: official_composite=0.5406 psnr=29.27 ssim=0.8721
#   Running inference on 460 images (alpha=0.2)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           29.1361 dB
# Mean SSIM:           0.868586
# Mean Delta PSNR:     +9.3104 dB
# Mean Delta SSIM:     +0.404202
#
# Composite Score:     0.53380477
# ==============================================
#
#   alpha=0.2: official_composite=0.5338 psnr=29.14 ssim=0.8686
#   Best alpha: 0.0 → composite=0.5415
#
#   Diagnostic score: 0.5360
#   Official score:   0.5415
#   Gap (diag-official): -0.0055
#
# Running CPU benchmark...
#   warmup 1/13: 3623 ms
#   warmup 2/13: 3452 ms
#   warmup 3/13: 3484 ms
#   MEASURE 4/13: 3329 ms
#   MEASURE 5/13: 3586 ms
#   MEASURE 6/13: 3437 ms
#   MEASURE 7/13: 3475 ms
#   MEASURE 8/13: 3362 ms
#   MEASURE 9/13: 3427 ms
#   MEASURE 10/13: 3549 ms
#   MEASURE 11/13: 3268 ms
#   MEASURE 12/13: 3346 ms
#   MEASURE 13/13: 3392 ms
#
# CPU benchmark: 3417.2 ± 94.0 ms/image (alpha=0.0)
#
# Result saved: {'run_id': 'run_lr3e4_charb', 'learning_rate': 0.0003, 'loss_weighting': 'charbonnier_only', 'patch_size': 128, 'epochs_trained': 25, 'still_improving_at_end': False, 'best_alpha': 0.0, 'notebook_diagnostic_score': 0.535974, 'official_evaluate_score': 0.541494, 'diag_vs_official_gap': -0.005521, 'mean_psnr': 29.288, 'mean_ssim': 0.872325, 'cpu_ms_per_image': 3417.21, 'cpu_ms_std': 94.02, 'timestamp': '2026-09-19T04:04:15'}
#
# #################################################################
# # Sweep run: run_lr3e4_ssim
# #################################################################
#
# ============================================================
# Starting: run_lr3e4_ssim
#   lr=3e-04  loss=charbonnier_plus_ssim  patch=128  epochs=25
# ============================================================
# [run_lr3e4_ssim] Epoch 1/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  1 | loss=0.1475 | score=0.1263 ↑ | psnr=22.28 | 64s
#
#   ⏱  Estimated remaining sweep time: 0.4 h (0 more runs + 24 more epochs this run)
# [run_lr3e4_ssim] Epoch 2/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  2 | loss=0.0913 | score=0.3950 ↑ | psnr=26.79 | 54s
# [run_lr3e4_ssim] Epoch 3/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  3 | loss=0.0656 | score=0.4374 ↑ | psnr=27.50 | 52s
# [run_lr3e4_ssim] Epoch 4/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  4 | loss=0.0597 | score=0.4443 ↑ | psnr=27.61 | 51s
# [run_lr3e4_ssim] Epoch 5/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  5 | loss=0.0603 | score=0.4435 | psnr=27.55 | 51s
# [run_lr3e4_ssim] Epoch 6/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  6 | loss=0.0592 | score=0.4581 ↑ | psnr=27.88 | 51s
# [run_lr3e4_ssim] Epoch 7/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  7 | loss=0.0561 | score=0.4648 ↑ | psnr=27.98 | 50s
# [run_lr3e4_ssim] Epoch 8/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  8 | loss=0.0545 | score=0.4883 ↑ | psnr=28.41 | 51s
# [run_lr3e4_ssim] Epoch 9/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  9 | loss=0.0525 | score=0.5036 ↑ | psnr=28.68 | 50s
# [run_lr3e4_ssim] Epoch 10/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 10 | loss=0.0498 | score=0.5090 ↑ | psnr=28.73 | 50s
# [run_lr3e4_ssim] Epoch 11/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 11 | loss=0.0491 | score=0.5198 ↑ | psnr=28.97 | 50s
# [run_lr3e4_ssim] Epoch 12/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 12 | loss=0.0481 | score=0.5239 ↑ | psnr=29.06 | 50s
# [run_lr3e4_ssim] Epoch 13/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 13 | loss=0.0477 | score=0.5294 ↑ | psnr=29.16 | 50s
# [run_lr3e4_ssim] Epoch 14/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 14 | loss=0.0462 | score=0.5327 ↑ | psnr=29.22 | 50s
# [run_lr3e4_ssim] Epoch 15/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 15 | loss=0.0469 | score=0.5368 ↑ | psnr=29.31 | 51s
# [run_lr3e4_ssim] Epoch 16/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 16 | loss=0.0464 | score=0.5393 ↑ | psnr=29.36 | 50s
# [run_lr3e4_ssim] Epoch 17/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 17 | loss=0.0455 | score=0.5428 ↑ | psnr=29.43 | 50s
# [run_lr3e4_ssim] Epoch 18/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 18 | loss=0.0445 | score=0.5452 ↑ | psnr=29.47 | 51s
# [run_lr3e4_ssim] Epoch 19/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 19 | loss=0.0448 | score=0.5456 ↑ | psnr=29.49 | 50s
# [run_lr3e4_ssim] Epoch 20/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 20 | loss=0.0449 | score=0.5475 ↑ | psnr=29.53 | 50s
# [run_lr3e4_ssim] Epoch 21/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 21 | loss=0.0446 | score=0.5487 ↑ | psnr=29.56 | 51s
# [run_lr3e4_ssim] Epoch 22/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 22 | loss=0.0445 | score=0.5495 ↑ | psnr=29.58 | 51s
# [run_lr3e4_ssim] Epoch 23/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 23 | loss=0.0441 | score=0.5503 ↑ | psnr=29.60 | 51s
# [run_lr3e4_ssim] Epoch 24/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 24 | loss=0.0441 | score=0.5514 ↑ | psnr=29.66 | 51s
# [run_lr3e4_ssim] Epoch 25/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 25 | loss=0.0432 | score=0.5517 ↑ | psnr=29.64 | 50s
#
# Sweeping alpha...
#   Running inference on 460 images (alpha=0.0)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           29.4334 dB
# Mean SSIM:           0.892410
# Mean Delta PSNR:     +9.6078 dB
# Mean Delta SSIM:     +0.428026
#
# Composite Score:     0.55419825
# ==============================================
#
#   alpha=0.0: official_composite=0.5542 psnr=29.43 ssim=0.8924
#   Running inference on 460 images (alpha=0.1)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           29.4392 dB
# Mean SSIM:           0.890577
# Mean Delta PSNR:     +9.6135 dB
# Mean Delta SSIM:     +0.426193
#
# Composite Score:     0.55369176
# ==============================================
#
#   alpha=0.1: official_composite=0.5537 psnr=29.44 ssim=0.8906
#   Running inference on 460 images (alpha=0.2)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           29.3185 dB
# Mean SSIM:           0.884942
# Mean Delta PSNR:     +9.4928 dB
# Mean Delta SSIM:     +0.420558
#
# Composite Score:     0.54676147
# ==============================================
#
#   alpha=0.2: official_composite=0.5468 psnr=29.32 ssim=0.8849
#   Best alpha: 0.0 → composite=0.5542
#
#   Diagnostic score: 0.5517
#   Official score:   0.5542
#   Gap (diag-official): -0.0025
#
# Running CPU benchmark...
#   warmup 1/13: 3854 ms
#   warmup 2/13: 3764 ms
#   warmup 3/13: 3474 ms
#   MEASURE 4/13: 3477 ms
#   MEASURE 5/13: 3449 ms
#   MEASURE 6/13: 3356 ms
#   MEASURE 7/13: 3437 ms
#   MEASURE 8/13: 3376 ms
#   MEASURE 9/13: 3433 ms
#   MEASURE 10/13: 3421 ms
#   MEASURE 11/13: 3463 ms
#   MEASURE 12/13: 3311 ms
#   MEASURE 13/13: 3401 ms
#
# CPU benchmark: 3412.6 ± 49.1 ms/image (alpha=0.0)
#
# Result saved: {'run_id': 'run_lr3e4_ssim', 'learning_rate': 0.0003, 'loss_weighting': 'charbonnier_plus_ssim', 'patch_size': 128, 'epochs_trained': 25, 'still_improving_at_end': False, 'best_alpha': 0.0, 'notebook_diagnostic_score': 0.551673, 'official_evaluate_score': 0.554198, 'diag_vs_official_gap': -0.002525, 'mean_psnr': 29.4334, 'mean_ssim': 0.89241, 'cpu_ms_per_image': 3412.55, 'cpu_ms_std': 49.08, 'timestamp': '2026-09-19T04:55:30'}
#
# =================================================================
# ALL RUNS COMPLETE
# =================================================================

# %% [markdown]
# ## Cell 13b — Extra Run: patch=192 (original notebook patch size)
# Run this cell **after Cell 13 finishes** to add a 5th data point.
#
# > **patch=192** gives the model more spatial context per training step — this is
# > the main thing different from the original notebook vs the current sweep (patch=128).

# %%
import datetime, pandas as pd

extra_cfg = dict(run_id='run_lr3e4_ssim_p192', lr=3e-4,
                 loss_weighting='charbonnier_plus_ssim', patch_size=192)

run_id = extra_cfg['run_id']
BASE_CFG['patch'] = 192  # override patch size for this run

# ── Train ──────────────────────────────────────────────────────────────────
run_dir  = SWEEP_ROOT / run_id
ckpt_dir = run_dir / 'checkpoints'
run_dir.mkdir(parents=True, exist_ok=True)
ckpt_dir.mkdir(parents=True, exist_ok=True)

random.seed(42); np.random.seed(42); torch.manual_seed(42)
if DEVICE.type == 'cuda': torch.cuda.manual_seed_all(42)

cfg = dict(BASE_CFG); cfg.update(lr=extra_cfg['lr'], patch=192)
model = Denoiser(CHANNELS, cfg['width'], cfg['blocks']).to(DEVICE)
ema   = copy.deepcopy(model).eval()
for p in ema.parameters(): p.requires_grad_(False)

loss_fn   = make_loss_fn(extra_cfg['loss_weighting'])
optimizer = torch.optim.AdamW(model.parameters(), lr=cfg['lr'], weight_decay=cfg['weight_decay'])
def lr_factor(epoch):
    if epoch < 3: return (epoch+1)/3
    progress = min(1, max(0, (epoch-3)/max(1, cfg['epochs']-3)))
    return .05 + .95*.5*(1+math.cos(math.pi*progress))
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_factor)
AMP    = cfg['amp'] and DEVICE.type == 'cuda'
scaler = torch.amp.GradScaler('cuda', enabled=AMP)
dataset = PairedPatches(train_ids, 192, cache=True)
loader  = DataLoader(dataset, batch_size=cfg['batch'], num_workers=0, pin_memory=True)

history=[]; best_score=-float('inf'); stale=0
best_ckpt = ckpt_dir / f'{run_id}_best.pth'

for epoch in range(cfg['epochs']):
    model.train(); losses=[]; started=time.perf_counter()
    nan_detected = False
    for noisy_b, clean_b in tqdm(loader, desc=f'[{run_id}] Epoch {epoch+1}/{cfg["epochs"]}'):
        noisy_b=noisy_b.to(DEVICE,non_blocking=True); clean_b=clean_b.to(DEVICE,non_blocking=True)
        optimizer.zero_grad(set_to_none=True)
        with torch.autocast(device_type=DEVICE.type, enabled=AMP):
            pred=model(noisy_b); loss=loss_fn(pred,clean_b)
        if not torch.isfinite(loss): print('NaN loss, stopping.'); nan_detected=True; break
        scaler.scale(loss).backward(); scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(),1.0)
        old_scale=scaler.get_scale(); scaler.step(optimizer); scaler.update()
        if scaler.get_scale()>=old_scale:
            with torch.no_grad():
                for ep,p in zip(ema.parameters(),model.parameters()): ep.lerp_(p,1-cfg['ema_decay'])
        losses.append(float(loss.detach()))
    if nan_detected: break
    _,rm=diagnostic_evaluate(model,val_ids,cfg['tile'],cfg['overlap'],DEVICE)
    _,em=diagnostic_evaluate(ema,   val_ids,cfg['tile'],cfg['overlap'],DEVICE)
    kind,winner,metrics=max([('raw',model,rm),('ema',ema,em)],key=lambda x:x[2]['score'])
    improved=metrics['score']>best_score
    if improved:
        best_score=metrics['score']
        torch.save({'model':{k:v.detach().cpu() for k,v in winner.state_dict().items()},
                    'config':dict(cfg),'epoch':epoch,'metrics':metrics,'split':SPLIT}, best_ckpt)
        stale=0
    else: stale+=1
    row=dict(epoch=epoch+1,loss=float(np.mean(losses)),lr=optimizer.param_groups[0]['lr'],
             raw_score=rm['score'],ema_score=em['score'],selected_score=metrics['score'],
             selected=kind,psnr=metrics['psnr'],ssim=metrics['ssim'],seconds=time.perf_counter()-started)
    history.append(row); scheduler.step()
    print(f"  Epoch {epoch+1:2d} | loss={row['loss']:.4f} | score={metrics['score']:.4f}"
          f"{'↑' if improved else ''} | psnr={metrics['psnr']:.2f} | {row['seconds']:.0f}s")
    pd.DataFrame(history).to_csv(run_dir/'training_history.csv', index=False)
    if stale>=cfg['patience']: print('Early stopping.'); break

# ── Evaluate ───────────────────────────────────────────────────────────────
best_alpha=0.0; best_official=-float('inf'); best_psnr=0.0; best_ssim_val=0.0
for alpha in ALPHA_CANDIDATES:
    try:
        official=official_eval_on_full_set(best_ckpt, run_id, alpha=alpha,
                                            tile=cfg['tile'], overlap=cfg['overlap'])
        print(f'  alpha={alpha:.1f}: composite={official["composite"]:.4f}')
        if official['composite']>best_official:
            best_official=official['composite']; best_alpha=alpha
            best_psnr=official['psnr']; best_ssim_val=official['ssim']
    except Exception as e: print(f'  Eval failed alpha={alpha}: {e}')

best_diag_score=max(r['selected_score'] for r in history)
gap=best_diag_score-best_official
try:    cpu_mean,cpu_std=cpu_benchmark(best_ckpt,alpha=best_alpha,tile=cfg['tile'],overlap=cfg['overlap'])
except: cpu_mean,cpu_std=float('nan'),float('nan')

row=dict(run_id=run_id,learning_rate=extra_cfg['lr'],loss_weighting=extra_cfg['loss_weighting'],
         patch_size=192,epochs_trained=len(history),still_improving_at_end=stale==0,
         best_alpha=best_alpha,notebook_diagnostic_score=round(best_diag_score,6),
         official_evaluate_score=round(best_official,6),diag_vs_official_gap=round(gap,6),
         mean_psnr=round(best_psnr,4),mean_ssim=round(best_ssim_val,6),
         cpu_ms_per_image=round(cpu_mean,2),cpu_ms_std=round(cpu_std,2),
         timestamp=datetime.datetime.now().isoformat(timespec='seconds'))
df_row=pd.DataFrame([row])
if RESULTS_CSV.exists(): df_row.to_csv(RESULTS_CSV,mode='a',header=False,index=False)
else: df_row.to_csv(RESULTS_CSV,index=False)
print(f'\nDone! official={best_official:.4f}  gap={gap:+.4f}')
BASE_CFG['patch']=128  # restore
# Out:
# [run_lr3e4_ssim_p192] Epoch 1/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  1 | loss=0.1479 | score=0.1253↑ | psnr=22.27 | 163s
# [run_lr3e4_ssim_p192] Epoch 2/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  2 | loss=0.0910 | score=0.3978↑ | psnr=26.81 | 210s
# [run_lr3e4_ssim_p192] Epoch 3/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  3 | loss=0.0638 | score=0.4368↑ | psnr=27.48 | 254s
# [run_lr3e4_ssim_p192] Epoch 4/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  4 | loss=0.0606 | score=0.4441↑ | psnr=27.63 | 75s
# [run_lr3e4_ssim_p192] Epoch 5/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  5 | loss=0.0602 | score=0.4508↑ | psnr=27.78 | 109s
# [run_lr3e4_ssim_p192] Epoch 6/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  6 | loss=0.0583 | score=0.4600↑ | psnr=27.91 | 65s
# [run_lr3e4_ssim_p192] Epoch 7/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  7 | loss=0.0558 | score=0.4644↑ | psnr=28.04 | 68s
# [run_lr3e4_ssim_p192] Epoch 8/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  8 | loss=0.0519 | score=0.4995↑ | psnr=28.58 | 66s
# [run_lr3e4_ssim_p192] Epoch 9/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch  9 | loss=0.0500 | score=0.5157↑ | psnr=28.87 | 66s
# [run_lr3e4_ssim_p192] Epoch 10/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 10 | loss=0.0490 | score=0.5194↑ | psnr=28.96 | 66s
# [run_lr3e4_ssim_p192] Epoch 11/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 11 | loss=0.0471 | score=0.5219↑ | psnr=29.01 | 95s
# [run_lr3e4_ssim_p192] Epoch 12/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 12 | loss=0.0477 | score=0.5311↑ | psnr=29.19 | 71s
# [run_lr3e4_ssim_p192] Epoch 13/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 13 | loss=0.0473 | score=0.5352↑ | psnr=29.28 | 101s
# [run_lr3e4_ssim_p192] Epoch 14/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 14 | loss=0.0451 | score=0.5404↑ | psnr=29.41 | 75s
# [run_lr3e4_ssim_p192] Epoch 15/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 15 | loss=0.0457 | score=0.5433↑ | psnr=29.44 | 97s
# [run_lr3e4_ssim_p192] Epoch 16/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 16 | loss=0.0449 | score=0.5460↑ | psnr=29.50 | 120s
# [run_lr3e4_ssim_p192] Epoch 17/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 17 | loss=0.0436 | score=0.5486↑ | psnr=29.56 | 59s
# [run_lr3e4_ssim_p192] Epoch 18/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 18 | loss=0.0435 | score=0.5507↑ | psnr=29.59 | 62s
# [run_lr3e4_ssim_p192] Epoch 19/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 19 | loss=0.0439 | score=0.5532↑ | psnr=29.65 | 63s
# [run_lr3e4_ssim_p192] Epoch 20/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 20 | loss=0.0435 | score=0.5544↑ | psnr=29.68 | 84s
# [run_lr3e4_ssim_p192] Epoch 21/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 21 | loss=0.0433 | score=0.5549↑ | psnr=29.70 | 101s
# [run_lr3e4_ssim_p192] Epoch 22/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 22 | loss=0.0432 | score=0.5556↑ | psnr=29.73 | 126s
# [run_lr3e4_ssim_p192] Epoch 23/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 23 | loss=0.0432 | score=0.5559↑ | psnr=29.73 | 125s
# [run_lr3e4_ssim_p192] Epoch 24/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 24 | loss=0.0422 | score=0.5562↑ | psnr=29.74 | 125s
# [run_lr3e4_ssim_p192] Epoch 25/25:   0%|          | 0/150 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
# Val eval:   0%|          | 0/46 [00:00<?, ?it/s]
#   Epoch 25 | loss=0.0423 | score=0.5571↑ | psnr=29.74 | 126s
#   Running inference on 460 images (alpha=0.0)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           29.5787 dB
# Mean SSIM:           0.894708
# Mean Delta PSNR:     +9.7530 dB
# Mean Delta SSIM:     +0.430325
#
# Composite Score:     0.56046462
# ==============================================
#
#   alpha=0.0: composite=0.5605
#   Running inference on 460 images (alpha=0.1)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           29.5681 dB
# Mean SSIM:           0.892576
# Mean Delta PSNR:     +9.7424 dB
# Mean Delta SSIM:     +0.428192
#
# Composite Score:     0.55931373
# ==============================================
#
#   alpha=0.1: composite=0.5593
#   Running inference on 460 images (alpha=0.2)...
# Official inference:   0%|          | 0/460 [00:00<?, ?it/s]
# ==============================================
# EVALUATION COMPLETE
# ==============================================
# Images scored:      460
# Mean PSNR:           29.4274 dB
# Mean SSIM:           0.886639
# Mean Delta PSNR:     +9.6017 dB
# Mean Delta SSIM:     +0.422255
#
# Composite Score:     0.55164778
# ==============================================
#
#   alpha=0.2: composite=0.5516
#   warmup 1/13: 4317 ms
#   warmup 2/13: 4200 ms
#   warmup 3/13: 4109 ms
#   MEASURE 4/13: 3813 ms
#   MEASURE 5/13: 3560 ms
#   MEASURE 6/13: 3712 ms
#   MEASURE 7/13: 3726 ms
#   MEASURE 8/13: 3764 ms
#   MEASURE 9/13: 3644 ms
#   MEASURE 10/13: 3565 ms
#   MEASURE 11/13: 3548 ms
#   MEASURE 12/13: 3627 ms
#   MEASURE 13/13: 3487 ms
#
# CPU benchmark: 3644.7 ± 101.0 ms/image (alpha=0.0)
#
# Done! official=0.5605  gap=-0.0034

# %% [markdown]
# ## Cell 14 — Final Summary Table & Conclusions

# %%
df = pd.read_csv(RESULTS_CSV).sort_values('official_evaluate_score', ascending=False)

print('\n=== HYPERPARAMETER SWEEP RESULTS (sorted by official score) ===\n')
display_cols = ['run_id', 'learning_rate', 'loss_weighting', 'epochs_trained',
                'best_alpha', 'notebook_diagnostic_score', 'official_evaluate_score',
                'diag_vs_official_gap', 'mean_psnr', 'mean_ssim',
                'cpu_ms_per_image', 'cpu_ms_std', 'still_improving_at_end']
print(df[display_cols].to_string(index=False))

winner = df.iloc[0]
baseline_score = 0.5233  # best alpha=0.1 score from original nafnet_script run

print(f'\n=== CONCLUSIONS ===')
print(f'Winner:          {winner["run_id"]}')
print(f'Official score:  {winner["official_evaluate_score"]:.4f}')
print(f'Baseline score:  {baseline_score:.4f}  (from nafnet_script, alpha=0.1)')
delta = winner["official_evaluate_score"] - baseline_score
if abs(delta) < 0.005:
    print(f'Verdict: ±{abs(delta):.4f} — original hyperparameters were ALREADY near-optimal.')
elif delta > 0:
    print(f'Verdict: +{delta:.4f} improvement — sweep found a MEANINGFULLY BETTER config!')
else:
    print(f'Verdict: {delta:.4f} — original hyperparameters were BETTER than all sweep configs.')

print(f'\nDiagnostic vs Official gap across runs:')
for _, r in df.iterrows():
    trusted = 'TRUSTED (gap < 0.01)' if abs(r['diag_vs_official_gap']) < 0.01 else 'SUSPECT'
    print(f"  {r['run_id']:30s}  gap={r['diag_vs_official_gap']:+.4f}  → {trusted}")
# Out:
# === HYPERPARAMETER SWEEP RESULTS (sorted by official score) ===
#
#              run_id  learning_rate        loss_weighting  epochs_trained  best_alpha  notebook_diagnostic_score  official_evaluate_score  diag_vs_official_gap  mean_psnr  mean_ssim  cpu_ms_per_image  cpu_ms_std  still_improving_at_end
# run_lr3e4_ssim_p192         0.0003 charbonnier_plus_ssim              25         0.0                   0.557061                 0.560465             -0.003404    29.5787   0.894708           3644.69      101.04                    True
#      run_lr3e4_ssim         0.0003 charbonnier_plus_ssim              25         0.0                   0.551673                 0.554198             -0.002525    29.4334   0.892410           3412.55       49.08                   False
#     run_lr3e4_charb         0.0003      charbonnier_only              25         0.0                   0.535974                 0.541494             -0.005521    29.2880   0.872325           3417.21       94.02                   False
#      run_lr1e4_ssim         0.0001 charbonnier_plus_ssim              25         0.2                   0.466170                 0.482606             -0.016436    28.1657   0.836897           3612.81       95.81                   False
#     run_lr1e4_charb         0.0001      charbonnier_only              25         0.2                   0.464608                 0.478610             -0.014002    28.1866   0.824816           3560.57       97.88                   False
#
# === CONCLUSIONS ===
# Winner:          run_lr3e4_ssim_p192
# Official score:  0.5605
# Baseline score:  0.5233  (from nafnet_script, alpha=0.1)
# Verdict: +0.0372 improvement — sweep found a MEANINGFULLY BETTER config!
#
# Diagnostic vs Official gap across runs:
#   run_lr3e4_ssim_p192             gap=-0.0034  → TRUSTED (gap < 0.01)
#   run_lr3e4_ssim                  gap=-0.0025  → TRUSTED (gap < 0.01)
#   run_lr3e4_charb                 gap=-0.0055  → TRUSTED (gap < 0.01)
#   run_lr1e4_ssim                  gap=-0.0164  → SUSPECT
#   run_lr1e4_charb                 gap=-0.0140  → SUSPECT

# %%
# ═══════════════════════════════════════════════════════════════════════════
# FINAL VERIFICATION CELL
# Assumes all earlier cells have run. Uses: SWEEP_ROOT, REPO_ROOT, DEVICE,
# Denoiser, predict, tiled, read_image, write_image, quantize, noisy_paths,
# TRAIN_NOISY_DIR, TRAIN_CLEAN_DIR, TEST_DIR, CHANNELS, BASE_CFG, math, F
# ═══════════════════════════════════════════════════════════════════════════
import subprocess, sys, tempfile, shutil, traceback, time
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from pathlib import Path
import torch

issues = []

# ── 1. IDENTIFY WINNING CHECKPOINT ──────────────────────────────────────────
print("="*65)
print("1. IDENTIFYING WINNING CHECKPOINT")
print("="*65)

WIN_RUN_ID  = 'run_lr3e4_ssim'
CKPT_PATH   = SWEEP_ROOT / WIN_RUN_ID / 'checkpoints' / f'{WIN_RUN_ID}_best.pth'

if not CKPT_PATH.exists():
    # Try reading the results CSV to find the actual winner
    if RESULTS_CSV.exists():
        df = pd.read_csv(RESULTS_CSV).sort_values('official_evaluate_score', ascending=False)
        WIN_RUN_ID = df.iloc[0]['run_id']
        CKPT_PATH  = SWEEP_ROOT / WIN_RUN_ID / 'checkpoints' / f'{WIN_RUN_ID}_best.pth'
        print(f"  Note: falling back to actual winner from CSV: {WIN_RUN_ID}")

if not CKPT_PATH.exists():
    issues.append(f"Checkpoint not found: {CKPT_PATH}")
    print(f"ERROR: checkpoint not found at {CKPT_PATH}")
else:
    size_mb = CKPT_PATH.stat().st_size / (1024*1024)
    print(f"  Checkpoint : {CKPT_PATH}")
    print(f"  Size       : {size_mb:.2f} MB")
    print(f"  Exists     : YES ✓")

# Relative path from REPO_ROOT for embedding in the standalone script
CKPT_REL = CKPT_PATH.relative_to(REPO_ROOT)
print(f"  Rel path   : {CKPT_REL}")

# ── 2. WRITE scripts/denoise.py ────────────────────────────────────────────
print("\n" + "="*65)
print("2. WRITING scripts/denoise.py")
print("="*65)

DENOISE_PY = REPO_ROOT / 'scripts' / 'denoise.py'

if DENOISE_PY.exists() and DENOISE_PY.stat().st_size > 0:
    print("  Existing content:")
    print("  " + "-"*60)
    print("  " + DENOISE_PY.read_text(encoding='utf-8').replace('\n', '\n  '))
    print("  " + "-"*60)
else:
    print("  scripts/denoise.py is empty or does not exist — writing fresh.")

CKPT_REL_STR = str(CKPT_REL).replace('\\', '/')

DENOISE_SRC = f'''#!/usr/bin/env python3
"""
denoise.py  — Mora SP Cup 2026 submission inference script.
Architecture: NAFNet-style Gated Residual U-Net (custom implementation).
Checkpoint  : {CKPT_REL_STR}
Alpha blend : 0.0 (pure neural, no wavelet blend)

USAGE:
    python scripts/denoise.py --noise_dir INPUT_DIR --denoised_dir OUTPUT_DIR
    python scripts/denoise.py --noise_dir INPUT_DIR --denoised_dir OUTPUT_DIR --device cpu
"""

import argparse, math, sys, time
from pathlib import Path

import numpy as np
from PIL import Image
import torch
import torch.nn.functional as F
from torch import nn


# ── Architecture (NAFNet-style Gated Residual U-Net) ──────────────────────
class ChannelNorm(nn.Module):
    def __init__(self, c):
        super().__init__()
        self.w = nn.Parameter(torch.ones(1, c, 1, 1))
        self.b = nn.Parameter(torch.zeros(1, c, 1, 1))
    def forward(self, x):
        dtype = x.dtype; z = x.float(); mu = z.mean(1, keepdim=True)
        z = (z - mu) * torch.rsqrt((z - mu).square().mean(1, keepdim=True) + 1e-6)
        return (z * self.w + self.b).to(dtype)

class GatedBlock(nn.Module):
    def __init__(self, c):
        super().__init__()
        self.n1 = ChannelNorm(c); self.n2 = ChannelNorm(c)
        self.expand = nn.Conv2d(c, 2*c, 1)
        self.depth  = nn.Conv2d(2*c, 2*c, 3, padding=1, groups=2*c)
        self.attn   = nn.Sequential(nn.AdaptiveAvgPool2d(1), nn.Conv2d(c, c, 1))
        self.project = nn.Conv2d(c, c, 1)
        self.f1 = nn.Conv2d(c, 2*c, 1); self.f2 = nn.Conv2d(c, c, 1)
        self.beta  = nn.Parameter(torch.zeros(1, c, 1, 1))
        self.gamma = nn.Parameter(torch.zeros(1, c, 1, 1))
    def forward(self, x):
        a, b = self.depth(self.expand(self.n1(x))).chunk(2, 1); z = a * b
        x = x + self.beta * self.project(z * self.attn(z))
        a, b = self.f1(self.n2(x)).chunk(2, 1)
        return x + self.gamma * self.f2(a * b)

class Denoiser(nn.Module):
    def __init__(self, channels=3, width=24, blocks=2):
        super().__init__(); self.channels = channels
        self.head = nn.Conv2d(channels, width, 3, padding=1)
        self.enc  = nn.ModuleList(); self.down = nn.ModuleList()
        self.up   = nn.ModuleList(); self.dec  = nn.ModuleList()
        c = width
        for _ in range(3):
            self.enc.append(nn.Sequential(*[GatedBlock(c) for _ in range(blocks)]))
            self.down.append(nn.Conv2d(c, 2*c, 2, stride=2)); c *= 2
        self.mid = nn.Sequential(*[GatedBlock(c) for _ in range(blocks + 2)])
        for _ in range(3):
            self.up.append(nn.Sequential(nn.Conv2d(c, 2*c, 1), nn.PixelShuffle(2))); c //= 2
            self.dec.append(nn.Sequential(*[GatedBlock(c) for _ in range(blocks)]))
        self.tail = nn.Conv2d(width, channels, 3, padding=1)
        nn.init.zeros_(self.tail.weight); nn.init.zeros_(self.tail.bias)
    def forward(self, x):
        h, w = x.shape[-2:]
        p = F.pad(x, (0, (-w) % 8, 0, (-h) % 8), mode='replicate')
        z = self.head(p); skips = []
        for enc, down in zip(self.enc, self.down): z = enc(z); skips.append(z); z = down(z)
        z = self.mid(z)
        for up, dec, s in zip(self.up, self.dec, reversed(skips)): z = dec(up(z) + s)
        return (p + self.tail(z))[..., :h, :w]


# ── Inference helpers ──────────────────────────────────────────────────────
def tiled(model, x, tile=384, overlap=64):
    h, w = x.shape[-2:]
    if h <= tile and w <= tile:
        return model(x).float()
    def starts(n):
        if n <= tile: return [0]
        return sorted(set(list(range(0, n - tile + 1, tile - overlap)) + [n - tile]))
    out = torch.zeros_like(x, dtype=torch.float32)
    wts = torch.zeros_like(x[:, :1], dtype=torch.float32)
    for top in starts(h):
        for left in starts(w):
            patch = x[..., top:top+tile, left:left+tile]; ph, pw = patch.shape[-2:]
            wy = torch.hann_window(ph, periodic=False, device=x.device).clamp_min(.05)
            wx = torch.hann_window(pw, periodic=False, device=x.device).clamp_min(.05)
            wt = (wy[:, None] * wx[None, :])[None, None]
            out[..., top:top+ph, left:left+pw] += model(patch).float() * wt
            wts[..., top:top+ph, left:left+pw] += wt
    return out / wts

@torch.inference_mode()
def predict(model, array, device, tile=384, overlap=64):
    x = torch.from_numpy(np.ascontiguousarray(
        array.transpose(2, 0, 1))).float()[None].to(device) / 255
    model.eval()
    result = tiled(model, x, tile, overlap).clamp(0, 1)[0].permute(1, 2, 0).cpu().numpy()
    return result

def read_image(path):
    with Image.open(path) as im:
        a = np.asarray(im)
    if a.ndim == 2: a = a[..., None]
    return np.array(a, copy=True)

def write_image(path, arr):
    out = np.rint(np.clip(arr, 0, 1) * 255).astype(np.uint8)
    Image.fromarray(out[..., 0] if out.shape[-1] == 1 else out).save(path)


# ── Main ───────────────────────────────────────────────────────────────────
def main():
    ap = argparse.ArgumentParser(description=__doc__)
    ap.add_argument('--noise_dir',    required=True,  type=Path)
    ap.add_argument('--denoised_dir', required=True,  type=Path)
    ap.add_argument('--device', default='auto', choices=['auto', 'cpu', 'cuda'])
    args = ap.parse_args()

    if args.device == 'auto':
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    else:
        device = torch.device(args.device)
    if device.type == 'cuda' and not torch.cuda.is_available():
        print('WARNING: CUDA unavailable, falling back to CPU.', file=sys.stderr)
        device = torch.device('cpu')
    print(f'Device: {{device}}', flush=True)

    # Resolve checkpoint relative to this script's location
    script_dir = Path(__file__).resolve().parent
    repo_root  = script_dir.parent
    ckpt_path  = repo_root / '{CKPT_REL_STR}'
    if not ckpt_path.exists():
        raise FileNotFoundError(f'Checkpoint not found: {{ckpt_path}}')

    state = torch.load(ckpt_path, map_location='cpu', weights_only=False)
    c     = state['config']
    model = Denoiser(c['channels'], c['width'], c['blocks'])
    model.load_state_dict(state['model'])
    model = model.to(device).eval()
    print(f'Loaded: {{ckpt_path.name}} (channels={{c["channels"]}}, '
          f'width={{c["width"]}}, blocks={{c["blocks"]}})', flush=True)

    args.denoised_dir.mkdir(parents=True, exist_ok=True)
    inputs = sorted(args.noise_dir.glob('*_noise.png'))
    if not inputs:
        raise FileNotFoundError(f'No *_noise.png files found in {{args.noise_dir}}')

    t0 = time.perf_counter()
    for p in inputs:
        img_id  = p.stem[:-len('_noise')]   # e.g. "461_noise" -> "461"
        out_name = f'{{img_id}}.png'
        arr  = read_image(p)
        pred = predict(model, arr, device, tile=384, overlap=64)
        write_image(args.denoised_dir / out_name, pred)
        print(f'  {{p.name}} -> {{out_name}}  '
              f'({{(time.perf_counter()-t0)*1000/max(1,inputs.index(p)+1):.0f}} ms/img avg)',
              flush=True)
    total = time.perf_counter() - t0
    print(f'Done: {{len(inputs)}} images in {{total:.1f}}s '
          f'({{total/len(inputs)*1000:.0f}} ms/image, device={{device}})', flush=True)

if __name__ == '__main__':
    main()
'''

DENOISE_PY.write_text(DENOISE_SRC, encoding='utf-8')
print(f"  Written: {DENOISE_PY}  ({DENOISE_PY.stat().st_size} bytes)")

# ── 3. SMOKE TEST on 20 public images ──────────────────────────────────────
print("\n" + "="*65)
print("3. SUBPROCESS SMOKE TEST (20 public images)")
print("="*65)

TEST_IDS = sorted(noisy_paths.keys())[:20]  # first 20 from public set
TMP_NOISY   = Path(tempfile.mkdtemp(prefix='mora_smoke_noisy_'))
TMP_DENOISED = Path(tempfile.mkdtemp(prefix='mora_smoke_out_'))

# Copy just 20 images to TMP_NOISY
for i in TEST_IDS:
    shutil.copy2(noisy_paths[i], TMP_NOISY / noisy_paths[i].name)
print(f"  Input  : {TMP_NOISY}  ({len(TEST_IDS)} images)")
print(f"  Output : {TMP_DENOISED}")

t_sub = time.perf_counter()
result = subprocess.run(
    [sys.executable, str(DENOISE_PY),
     '--noise_dir', str(TMP_NOISY),
     '--denoised_dir', str(TMP_DENOISED),
     '--device', 'auto'],
    capture_output=True, text=True
)
elapsed_sub = time.perf_counter() - t_sub

print(f"\n  --- STDOUT ---\n{result.stdout}")
if result.stderr.strip():
    print(f"  --- STDERR ---\n{result.stderr}")

if result.returncode != 0:
    issues.append(f"subprocess failed with exit code {result.returncode}")
    print(f"\n  ERROR: subprocess exited with code {result.returncode}. Stopping.")
    for issue in issues:
        print(f"  ✗ {issue}")
    raise SystemExit("Fix the above errors before continuing.")

print(f"  Subprocess wall-clock: {elapsed_sub:.1f}s  "
      f"({elapsed_sub/len(TEST_IDS)*1000:.0f} ms/img avg)")

# ── 4. PIXEL-FOR-PIXEL CROSS-CHECK ─────────────────────────────────────────
print("\n" + "="*65)
print("4. PIXEL CROSS-CHECK (CLI vs notebook predict())")
print("="*65)

state_chk = torch.load(CKPT_PATH, map_location='cpu', weights_only=False)
c_chk     = state_chk['config']
net_chk   = Denoiser(c_chk['channels'], c_chk['width'], c_chk['blocks'])
net_chk.load_state_dict(state_chk['model'])
net_chk   = net_chk.to(DEVICE).eval()

TOL = 1.0 / 255.0
all_pass = True
fail_list = []
for i in TEST_IDS:
    arr = read_image(noisy_paths[i])
    # Notebook reference prediction
    ref = np.rint(np.clip(predict(net_chk, arr, DEVICE, 384, 64), 0, 1) * 255).astype(np.uint8)
    # CLI output
    cli_out_path = TMP_DENOISED / f'{i:03d}.png'
    if not cli_out_path.exists():
        all_pass = False
        fail_list.append(f"  MISSING output: {cli_out_path.name}")
        continue
    cli = np.array(Image.open(cli_out_path))
    if cli.ndim == 2: cli = cli[..., None]
    max_diff = np.abs(ref.astype(np.float32) - cli.astype(np.float32)).max() / 255.0
    if max_diff > TOL:
        all_pass = False
        fail_list.append(f"  Image {i:03d}: max pixel diff = {max_diff:.6f} (threshold {TOL:.6f})")

if all_pass:
    print(f"  PASS — all {len(TEST_IDS)} images match within {TOL:.6f} tolerance ✓")
else:
    issues.append("Pixel cross-check failed")
    print("  FAIL — mismatches detected:")
    for f in fail_list: print(f)

# ── 5. FULL SMOKE TEST on REAL SUBMISSION images ───────────────────────────
print("\n" + "="*65)
print("5. SUBMISSION SMOKE TEST (competition_data/submissions/noisy)")
print("="*65)

SUB_NOISY    = TEST_DIR
SUB_DENOISED = REPO_ROOT / 'competition_data' / 'submissions' / 'denoised'
SUB_DENOISED.mkdir(parents=True, exist_ok=True)

sub_inputs = sorted(SUB_NOISY.glob('*_noise.png'))
if not sub_inputs:
    print(f"  SKIP: no *_noise.png files found in {SUB_NOISY}")
    print("  (The real 20 test images 461-480 are not present locally — this is expected.)")
else:
    t_sub2 = time.perf_counter()
    r2 = subprocess.run(
        [sys.executable, str(DENOISE_PY),
         '--noise_dir', str(SUB_NOISY),
         '--denoised_dir', str(SUB_DENOISED),
         '--device', 'auto'],
        capture_output=True, text=True
    )
    elapsed_sub2 = time.perf_counter() - t_sub2
    print(f"  {r2.stdout}")
    if r2.returncode != 0:
        issues.append("Submission script failed on real test images")
        print(f"  STDERR:\n{r2.stderr}")
    else:
        created = sorted(SUB_DENOISED.glob('*.png'))
        expected_names = {f'{i}.png' for i in range(461, 481)}
        actual_names   = {p.name for p in created}
        if actual_names == expected_names:
            print(f"  Files created : {len(created)} ✓  (461.png … 480.png)")
        else:
            issues.append(f"Wrong output files: {actual_names ^ expected_names}")
            print(f"  FAIL — expected {expected_names}, got {actual_names}")
        print(f"  Total wall-clock: {elapsed_sub2:.1f}s  ({elapsed_sub2/len(sub_inputs)*1000:.0f} ms/img)")

# ── 6. VISUAL CHECK (inline images) ─────────────────────────────────────────
print("\n" + "="*65)
print("6. VISUAL SPOT CHECK")
print("="*65)

sample_ids = TEST_IDS[:3]
fig, axes = plt.subplots(len(sample_ids), 2, figsize=(14, 4*len(sample_ids)))
for row_ax, i in zip(axes, sample_ids):
    noisy_arr = read_image(noisy_paths[i])
    cli_out   = TMP_DENOISED / f'{i:03d}.png'
    denoised_arr = np.array(Image.open(cli_out)) if cli_out.exists() else noisy_arr
    row_ax[0].imshow(noisy_arr[::4, ::4].squeeze(), cmap='gray' if CHANNELS==1 else None)
    row_ax[0].set_title(f'Input noisy — img {i:03d}'); row_ax[0].axis('off')
    row_ax[1].imshow(denoised_arr[::4, ::4].squeeze(), cmap='gray' if CHANNELS==1 else None)
    row_ax[1].set_title(f'Denoised output — img {i:03d}'); row_ax[1].axis('off')
plt.tight_layout(); plt.show()

# ── 7. FORCED CPU TIMING ────────────────────────────────────────────────────
print("\n" + "="*65)
print("7. FORCED CPU INFERENCE TIMING (competition-relevant)")
print("="*65)

TMP_CPU_OUT = Path(tempfile.mkdtemp(prefix='mora_cpu_'))
t_cpu = time.perf_counter()
r_cpu = subprocess.run(
    [sys.executable, str(DENOISE_PY),
     '--noise_dir', str(TMP_NOISY),
     '--denoised_dir', str(TMP_CPU_OUT),
     '--device', 'cpu'],
    capture_output=True, text=True
)
elapsed_cpu = time.perf_counter() - t_cpu
print(f"  {r_cpu.stdout}")
if r_cpu.returncode != 0:
    issues.append("CPU forced run failed")
    print(f"  STDERR:\n{r_cpu.stderr}")
else:
    print(f"  CPU total ({len(TEST_IDS)} images): {elapsed_cpu:.1f}s")
    print(f"  CPU mean  : {elapsed_cpu/len(TEST_IDS)*1000:.0f} ms/image")

# Cleanup temp dirs
shutil.rmtree(TMP_NOISY,   ignore_errors=True)
shutil.rmtree(TMP_DENOISED, ignore_errors=True)
shutil.rmtree(TMP_CPU_OUT, ignore_errors=True)

# ── FINAL VERDICT ────────────────────────────────────────────────────────────
print("\n" + "="*65)
if not issues:
    print("SUBMISSION SCRIPT VERIFIED AND READY")
else:
    print("ISSUES FOUND — fix before submitting:")
    for issue in issues:
        print(f"  ✗ {issue}")
print("="*65)
# Out:
# =================================================================
# 1. IDENTIFYING WINNING CHECKPOINT
# =================================================================
#   Checkpoint : c:\Daniel\Projects\moraspcup-altf4\sweep_outputs\run_lr3e4_ssim\checkpoints\run_lr3e4_ssim_best.pth
#   Size       : 6.25 MB
#   Exists     : YES ✓
#   Rel path   : sweep_outputs\run_lr3e4_ssim\checkpoints\run_lr3e4_ssim_best.pth
#
# =================================================================
# 2. WRITING scripts/denoise.py
# =================================================================
#   scripts/denoise.py is empty or does not exist — writing fresh.
#   Written: c:\Daniel\Projects\moraspcup-altf4\scripts\denoise.py  (7779 bytes)
#
# =================================================================
# 3. SUBPROCESS SMOKE TEST (20 public images)
# =================================================================
#   Input  : C:\Users\Daniel\AppData\Local\Temp\mora_smoke_noisy_tc8eedlh  (20 images)
#   Output : C:\Users\Daniel\AppData\Local\Temp\mora_smoke_out_mchfypdr
#
#   --- STDOUT ---
# Device: cuda
# Loaded: run_lr3e4_ssim_best.pth (channels=3, width=24, blocks=2)
#   001_noise.png -> 001.png  (1040 ms/img avg)
#   002_noise.png -> 002.png  (752 ms/img avg)
#   003_noise.png -> 003.png  (702 ms/img avg)
#   004_noise.png -> 004.png  (664 ms/img avg)
#   005_noise.png -> 005.png  (636 ms/img avg)
#   006_noise.png -> 006.png  (639 ms/img avg)
#   007_noise.png -> 007.png  (646 ms/img avg)
#   008_noise.png -> 008.png  (675 ms/img avg)
#   009_noise.png -> 009.png  (674 ms/img avg)
#   010_noise.png -> 010.png  (663 ms/img avg)
#   011_noise.png -> 011.png  (658 ms/img avg)
#   012_noise.png -> 012.png  (652 ms/img avg)
#   013_noise.png -> 013.png  (654 ms/img avg)
#   014_noise.png -> 014.png  (658 ms/img avg)
#   015_noise.png -> 015.png  (659 ms/img avg)
#   016_noise.png -> 016.png  (656 ms/img avg)
#   017_noise.png -> 017.png  (646 ms/img avg)
#   018_noise.png -> 018.png  (643 ms/img avg)
#   019_noise.png -> 019.png  (644 ms/img avg)
#   020_noise.png -> 020.png  (639 ms/img avg)
# Done: 20 images in 12.8s (639 ms/image, device=cuda)
#
#   Subprocess wall-clock: 17.7s  (883 ms/img avg)
#
# =================================================================
# 4. PIXEL CROSS-CHECK (CLI vs notebook predict())
# =================================================================
#   PASS — all 20 images match within 0.003922 tolerance ✓
#
# =================================================================
# 5. SUBMISSION SMOKE TEST (competition_data/submissions/noisy)
# =================================================================
#   SKIP: no *_noise.png files found in c:\Daniel\Projects\moraspcup-altf4\competition_data\submissions\noisy
#   (The real 20 test images 461-480 are not present locally — this is expected.)
#
# =================================================================
# 6. VISUAL SPOT CHECK
# =================================================================
# =================================================================
# 7. FORCED CPU INFERENCE TIMING (competition-relevant)
# =================================================================
#   Device: cpu
# Loaded: run_lr3e4_ssim_best.pth (channels=3, width=24, blocks=2)
#   001_noise.png -> 001.png  (3980 ms/img avg)
#   002_noise.png -> 002.png  (4140 ms/img avg)
#   003_noise.png -> 003.png  (4340 ms/img avg)
#   004_noise.png -> 004.png  (4361 ms/img avg)
#   005_noise.png -> 005.png  (4369 ms/img avg)
#   006_noise.png -> 006.png  (4371 ms/img avg)
#   007_noise.png -> 007.png  (4373 ms/img avg)
#   008_noise.png -> 008.png  (4397 ms/img avg)
#   009_noise.png -> 009.png  (4401 ms/img avg)
#   010_noise.png -> 010.png  (4509 ms/img avg)
#   011_noise.png -> 011.png  (5139 ms/img avg)
#   012_noise.png -> 012.png  (6031 ms/img avg)
#   013_noise.png -> 013.png  (6715 ms/img avg)
#   014_noise.png -> 014.png  (7289 ms/img avg)
#   015_noise.png -> 015.png  (7253 ms/img avg)
#   016_noise.png -> 016.png  (7177 ms/img avg)
#   017_noise.png -> 017.png  (7048 ms/img avg)
#   018_noise.png -> 018.png  (6906 ms/img avg)
#   019_noise.png -> 019.png  (6772 ms/img avg)
#   020_noise.png -> 020.png  (6642 ms/img avg)
# Done: 20 images in 132.8s (6642 ms/image, device=cpu)
#
#   CPU total (20 images): 135.1s
#   CPU mean  : 6755 ms/image
#
# =================================================================
# SUBMISSION SCRIPT VERIFIED AND READY
# =================================================================
